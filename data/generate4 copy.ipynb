# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"./data_nasabah.csv")
df
# Out:
#       Unnamed: 0                   debtor_name        debtor_nik  \
# 0              0              Cemplunk Zulaika  4133431716345918
# 1              1         Clara Padmasari, M.Pd  7873621118387801
# 2              2  Puti Cinthia Oktaviani, S.IP  9937369990430445
# 3              3          Lalita Astuti, M.TI.  2071079715934185
# 4              4                Daliman Kusumo  8852740896362143
# ...          ...                           ...               ...
# 4995        4995                 Farah Budiman  1119427982364147
# 4996        4996          Rahmi Permata, S.Sos  6199571700348089
# 4997        4997               Vega Zulkarnain  4792712372200728
# 4998        4998            Karimah Adriansyah  7096542170234569
# 4999        4999                  Alika Januar  4595204238824022
#
#                                          debtor_address        debtor_number  \
# 0     Jalan Raya Setiabudhi No. 857\nBanjarbaru, KR ...   +62 (102) 776 3467
# ...

# %%
df.drop("Unnamed: 0", axis=1, inplace=True)

# %%
education_levels = ['SD', 'SMP', 'SMA', 'D1', 'D2', 'D3', 'D4', 'S1', 'S2', 'S3']

debtor_education_level = np.random.choice(education_levels, 5000, p=[0.07777777777777778, 0.3, 0.07777777777777778, 0.07777777777777778, 0.07777777777777778, 0.07777777777777778, 0.07777777777777778, 0.07777777777777778, 0.07777777777777778, 0.07777777777777778])
df["debtor_education_level"] = debtor_education_level

df.head()
# Out:
#                     debtor_name        debtor_nik  \
# 0              Cemplunk Zulaika  4133431716345918
# 1         Clara Padmasari, M.Pd  7873621118387801
# 2  Puti Cinthia Oktaviani, S.IP  9937369990430445
# 3          Lalita Astuti, M.TI.  2071079715934185
# 4                Daliman Kusumo  8852740896362143
#
#                                       debtor_address        debtor_number  \
# 0  Jalan Raya Setiabudhi No. 857\nBanjarbaru, KR ...   +62 (102) 776 3467
# 1  Jalan Cihampelas No. 4\nPekanbaru, Sulawesi Se...   +62 (808) 299 5117
# 2           Jl. Wonoayu No. 68\nSemarang, Riau 98101  +62 (0582) 416 0892
# 3    Gg. Sentot Alibasa No. 781\nPontianak, SU 76993   +62 (737) 295-9765
# 4   Jl. Ronggowarsito No. 0\nTanjungpinang, NB 06297  +62 (0740) 390 0826
#
#                            debtor_company debtor_gender  \
# 0         CV Nugroho Melani (Persero) Tbk     perempuan
# 1                              UD Hidayat     laki-laki
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 52 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   debtor_name             5000 non-null   object
#  1   debtor_nik              5000 non-null   int64
#  2   debtor_address          5000 non-null   object
#  3   debtor_number           5000 non-null   object
#  4   debtor_company          5000 non-null   object
#  5   debtor_gender           5000 non-null   object
#  6   debtor_education_level  5000 non-null   object
#  7   employment_type         5000 non-null   object
#  8   number_of_dependents    5000 non-null   int64
#  9   net_income              5000 non-null   float64
#  10  payment_date            5000 non-null   object
#  11  loan_amount             5000 non-null   float64
#  12  amount_of_late          5000 non-null   int64
#  13  late_payment_amount     5000 non-null   int64
# ...

# %%
df["debtor_education_level"]
# Out:
# 0        D3
# 1        S2
# 2        SD
# 3        S1
# 4       SMA
#        ...
# 4995    SMP
# 4996     D1
# 4997    SMP
# 4998     SD
# 4999     S2
# Name: debtor_education_level, Length: 5000, dtype: object

# %%
df.to_csv("./data_nasabah.csv")

# %%
df2 = df["debtor_education_level"]
df2.to_csv("education.csv")
