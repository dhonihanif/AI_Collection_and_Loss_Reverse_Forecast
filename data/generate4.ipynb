# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"./data_nasabah.csv")
df
# Out:
#       Unnamed: 0                   debtor_name        debtor_nik  \
# 0              0              Cemplunk Zulaika  4133431716345918
# 1              1         Clara Padmasari, M.Pd  7873621118387801
# 2              2  Puti Cinthia Oktaviani, S.IP  9937369990430445
# 3              3          Lalita Astuti, M.TI.  2071079715934185
# 4              4                Daliman Kusumo  8852740896362143
# ...          ...                           ...               ...
# 4995        4995                 Farah Budiman  1119427982364147
# 4996        4996          Rahmi Permata, S.Sos  6199571700348089
# 4997        4997               Vega Zulkarnain  4792712372200728
# 4998        4998            Karimah Adriansyah  7096542170234569
# 4999        4999                  Alika Januar  4595204238824022
#
#                                          debtor_address        debtor_number  \
# 0     Jalan Raya Setiabudhi No. 857\nBanjarbaru, KR ...   +62 (102) 776 3467
# ...

# %%
df2 = pd.read_csv(r"C:\Users\DHONI HANIF\OneDrive\Documents\AI_Collection_and_Loss_Reverse_Forecast\modelling\nasabah\clustering\data\data_for_classification.csv")
df2
# Out:
#       Unnamed: 0  net_income   loan_amount  amount_of_late  \
# 0              0  15500000.0  6.250000e+07             2.0
# 1              1  17500000.0  7.083333e+07            31.0
# 2              2  17500000.0  5.933333e+07             0.0
# 3              3  15500000.0  6.116667e+07            64.0
# 4              4   8700000.0  5.616667e+07            14.0
# ...          ...         ...           ...             ...
# 4995        4995  15500000.0  8.800000e+07           106.0
# 4996        4996  19000000.0  5.100000e+07            25.0
# 4997        4997  12700000.0  6.150000e+07            53.0
# 4998        4998  13700000.0  5.900000e+07            27.0
# 4999        4999  18500000.0  8.116667e+07           118.0
#
#       late_payment_amount  credit_score  arrears_amounts  loss_reverse  \
# 0                     1.0         670.0              0.0  0.000000e+00
# 1                     3.0         402.0              1.0  1.770833e+07
# ...

# %%
df.drop("Unnamed: 0", axis=1, inplace=True)
df2.drop("Unnamed: 0", axis=1, inplace=True)

# %%
df["credit_risk"] = df2["credit_risk"]
df.to_csv("AI_Collection_and_Loss_Reverse_Forecast.csv")
