# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_kolektor = pd.read_csv(r"C:\Users\DHONI HANIF\OneDrive\Documents\AI Collection and Loss Reverse Forecast\data_preparation\EDA\Univariate_bivariate_multivariate\Univariate_Analysis\new_kolektor.csv")
df_kolektor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             1000 non-null   int64
#  1   time_to_collect        1000 non-null   int64
#  2   avg_bill_methods       1000 non-null   object
#  3   debtor_volume_handled  1000 non-null   int64
#  4   bill_amount_collected  1000 non-null   int64
#  5   total_actual           1000 non-null   int64
#  6   total_cost             1000 non-null   int64
#  7   success_rate           1000 non-null   float64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 62.6+ KB

# %%
df_kolektor["avg_bill_methods"] = df_kolektor["avg_bill_methods"].astype("category")

df_kolektor.drop("Unnamed: 0", axis=1, inplace=True)

# %%
df_kolektor
# Out:
#      time_to_collect  avg_bill_methods  debtor_volume_handled  \
# 0                  0         sms or WA                      7
# 1                 11         panggilan                     35
# 2                  4         sms or WA                      6
# 3                 29  datang ke tempat                     63
# 4                 22  datang ke tempat                     35
# ..               ...               ...                    ...
# 995               10   surat panggilan                     25
# 996               24  datang ke tempat                     30
# 997               21  datang ke tempat                     62
# 998               12         panggilan                     46
# 999                5         sms or WA                     19
#
#      bill_amount_collected  total_actual  total_cost  success_rate
# 0                 14400000      35700000      277706          40.0
# 1                 79000000     160500000    22382611          49.0
# ...

# %% [markdown]
# avg_time vs avg_bill_methods

# %%
fig, ax = plt.subplots(figsize=(10, 3), layout="constrained")
sns.boxplot(data=df_kolektor, x="avg_bill_methods", y="time_to_collect", ax=ax)
plt.show()

# %% [markdown]
# debtor_volume_handled vs avg_bill_methods

# %%
fig, ax = plt.subplots(figsize=(10, 3), layout="constrained")
sns.boxplot(data=df_kolektor, x="avg_bill_methods", y="debtor_volume_handled", ax=ax)
plt.show()

# %% [markdown]
# success_rate vs avg_bill_methods

# %%
fig, ax = plt.subplots(figsize=(10, 3), layout="constrained")
sns.boxplot(data=df_kolektor, x="avg_bill_methods", y="success_rate", ax=ax)
plt.show()

# %% [markdown]
# bill_amount_collected vs avg_bill_methods

# %%
fig, ax = plt.subplots(figsize=(10, 3), layout="constrained")
sns.boxplot(data=df_kolektor, x="avg_bill_methods", y="bill_amount_collected", ax=ax)
plt.show()

# %% [markdown]
# total_actual vs avg_bill_methods

# %%
fig, ax = plt.subplots(figsize=(10, 3), layout="constrained")
sns.boxplot(data=df_kolektor, x="avg_bill_methods", y="total_actual", ax=ax)
plt.show()

# %% [markdown]
# total_cost vs avg_bill_methods

# %%
fig, ax = plt.subplots(figsize=(10, 3), layout="constrained")
sns.boxplot(data=df_kolektor, x="avg_bill_methods", y="total_cost", ax=ax)
plt.show()

# %%
sns.pairplot(data=df_kolektor, kind="reg", diag_kind="hist")
# Out:
# c:\Users\DHONI HANIF\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
fig, ax = plt.subplots(1, 8, figsize=(20, 5), layout="constrained")

for i in range(7):
    sns.lineplot(data=df_kolektor, x=df_kolektor.loc[:, "time_to_collect"], y=df_kolektor.iloc[:, i], ax=ax[i])
plt.show()

# %%
fig, ax = plt.subplots(1, 8, figsize=(20, 5), layout="constrained")

for i in range(7):
    sns.lineplot(data=df_kolektor, x=df_kolektor.loc[:, "debtor_volume_handled"], y=df_kolektor.iloc[:, i], ax=ax[i])
plt.show()

# %%
fig, ax = plt.subplots(1, 8, figsize=(20, 5), layout="constrained")

for i in range(7):
    sns.lineplot(data=df_kolektor, x=df_kolektor.loc[:, "success_rate"], y=df_kolektor.iloc[:, i], ax=ax[i])
plt.show()

# %%
fig, ax = plt.subplots(1, 8, figsize=(20, 5), layout="constrained")

for i in range(7):
    sns.lineplot(data=df_kolektor, x=df_kolektor.loc[:, "bill_amount_collected"], y=df_kolektor.iloc[:, i], ax=ax[i])
plt.show()

# %%
fig, ax = plt.subplots(1, 8, figsize=(20, 5), layout="constrained")

for i in range(7):
    sns.lineplot(data=df_kolektor, x=df_kolektor.loc[:, "total_actual"], y=df_kolektor.iloc[:, i], ax=ax[i])
plt.show()

# %%
fig, ax = plt.subplots(1, 8, figsize=(20, 5), layout="constrained")

for i in range(7):
    sns.lineplot(data=df_kolektor, x=df_kolektor.loc[:, "total_cost"], y=df_kolektor.iloc[:, i], ax=ax[i])
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
bill_methods = LabelEncoder().fit(df_kolektor["avg_bill_methods"])

df_kolektor["avg_bill_methods"] = bill_methods.transform(df_kolektor["avg_bill_methods"])
df_kolektor.head(5)
# Out:
#    time_to_collect  avg_bill_methods  debtor_volume_handled  \
# 0                0                 2                      7
# 1               11                 1                     35
# 2                4                 2                      6
# 3               29                 0                     63
# 4               22                 0                     35
#
#    bill_amount_collected  total_actual  total_cost  success_rate
# 0               14400000      35700000      277706          40.0
# 1               79000000     160500000    22382611          49.0
# 2                7100000      26700000      205389          27.0
# 3              782000000    1395000000   482942548          56.0
# 4              346000000     485500000   151035603          71.0

# %%
fig, ax = plt.subplots(figsize=(12, 8), layout="constrained")
sns.heatmap(data=df_kolektor.corr(), linecolor="white", linewidths=.2, annot=True, cmap="winter", ax=ax)
plt.show()

# %%
bill_method = np.unique(bill_methods.inverse_transform(df_kolektor["avg_bill_methods"]))
bill_method2 = np.unique(bill_methods.transform(bill_method))
print({i: j for i, j in zip(bill_method, bill_method2)})
# Out:
# {'datang ke tempat': 0, 'panggilan': 1, 'sms or WA': 2, 'surat panggilan': 3}
