# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_nasabah = pd.read_csv(r"C:\Users\DHONI HANIF\OneDrive\Documents\AI_Collection_and_Loss_Reverse_Forecast\data_preparation\EDA\Univariate_bivariate_multivariate\Univariate_Analysis\new_nasabah.csv")
df_nasabah.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              5000 non-null   int64
#  1   debtor_gender           5000 non-null   object
#  2   debtor_education_level  5000 non-null   object
#  3   employment_type         5000 non-null   object
#  4   number_of_dependents    5000 non-null   int64
#  5   net_income              5000 non-null   float64
#  6   payment_date            5000 non-null   int64
#  7   loan_amount             5000 non-null   float64
#  8   amount_of_late          5000 non-null   int64
#  9   late_payment_amount     5000 non-null   int64
#  10  credit_risk             5000 non-null   object
#  11  credit_score            5000 non-null   int64
#  12  arrears_amounts         5000 non-null   int64
#  13  aset                    5000 non-null   int64
#  14  loss_reverse            5000 non-null   float64
#  15  aging                   5000 non-null   object
#  16  debtor_zip              5000 non-null   int64
#  17  debtor_rt               5000 non-null   int64
#  18  debtor_rw               5000 non-null   int64
#  19  debtor_birth_place      5000 non-null   object
#  20  debtor_age              5000 non-null   int64
#  21  debtor_occupation       5000 non-null   object
#  22  debtor_marital_status   5000 non-null   object
#  23  tenor                   5000 non-null   int64
# dtypes: float64(3), int64(13), object(8)
# memory usage: 937.6+ KB

# %%
for i in df_nasabah.columns:
    if df_nasabah[i].dtype == "object":
        df_nasabah[i] = df_nasabah[i].astype("category")
df_nasabah.drop("Unnamed: 0", axis=1, inplace=True)
df_nasabah.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   debtor_gender           5000 non-null   category
#  1   debtor_education_level  5000 non-null   category
#  2   employment_type         5000 non-null   category
#  3   number_of_dependents    5000 non-null   int64
#  4   net_income              5000 non-null   float64
#  5   payment_date            5000 non-null   int64
#  6   loan_amount             5000 non-null   float64
#  7   amount_of_late          5000 non-null   int64
#  8   late_payment_amount     5000 non-null   int64
#  9   credit_risk             5000 non-null   category
#  10  credit_score            5000 non-null   int64
#  11  arrears_amounts         5000 non-null   int64
#  12  aset                    5000 non-null   int64
#  13  loss_reverse            5000 non-null   float64
#  14  aging                   5000 non-null   category
#  15  debtor_zip              5000 non-null   int64
#  16  debtor_rt               5000 non-null   int64
#  17  debtor_rw               5000 non-null   int64
#  18  debtor_birth_place      5000 non-null   category
#  19  debtor_age              5000 non-null   int64
#  20  debtor_occupation       5000 non-null   category
#  21  debtor_marital_status   5000 non-null   category
#  22  tenor                   5000 non-null   int64
# dtypes: category(8), float64(3), int64(12)
# memory usage: 799.4 KB

# %% [markdown]
# Gender x education

# %%
# Bivariate Analysis of Categorical Variables Gender vs Education
ax = sns.countplot(data=df_nasabah, x="debtor_education_level", hue="debtor_gender")
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment="right")
plt.legend(bbox_to_anchor=(1, 0.2))
plt.tight_layout()
plt.show()

# %% [markdown]
# Gender x Martial Status

# %%
# Bivariate Analysis of Categorical Variables Gender vs Martial Status
ax = sns.countplot(data=df_nasabah, x="debtor_marital_status", hue="debtor_gender")
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment="right")
plt.legend(bbox_to_anchor=(1, 0.2))
plt.tight_layout()
plt.show()

# %% [markdown]
# aging vs martial status

# %%
# Bivariate Analysis of Categorical Variables aging vs Martial Status
ax = sns.countplot(data=df_nasabah, x="aging", hue="debtor_marital_status")
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment="right")
plt.legend(bbox_to_anchor=(1, 0.2))
plt.tight_layout()
plt.show()

# %% [markdown]
# aging vs education

# %%
# Bivariate Analysis of Categorical Variables aging vs education
ax = sns.countplot(data=df_nasabah, x="debtor_education_level", hue="aging")
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment="right")
plt.legend(bbox_to_anchor=(1, 0.2))
plt.tight_layout()
plt.show()

# %% [markdown]
# aging vs employment type

# %%
# Bivariate Analysis of Categorical Variables aging vs Martial Status
ax = sns.countplot(data=df_nasabah, x="employment_type", hue="aging")
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment="right")
plt.legend(bbox_to_anchor=(1, 0.2))
plt.tight_layout()
plt.show()

# %% [markdown]
# Education x Martial Status

# %%
# Bivariate Analysis of Categorical Variables Education vs Martial Status
ax = sns.countplot(data=df_nasabah, x="debtor_education_level", hue="debtor_marital_status")
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment="right")
plt.legend(bbox_to_anchor=(1, 0.2))
plt.tight_layout()
plt.show()

# %% [markdown]
# Age x Gender

# %%
sns.boxplot(data=df_nasabah, x="debtor_gender", y="debtor_age")
# Out:
# <Axes: xlabel='debtor_gender', ylabel='debtor_age'>

# %% [markdown]
# aging vs age

# %%
sns.boxplot(data=df_nasabah, x="aging", y="debtor_age")
# Out:
# <Axes: xlabel='aging', ylabel='debtor_age'>

# %% [markdown]
# Age x Martial Status

# %%
sns.boxplot(data=df_nasabah, x="debtor_marital_status", y="age")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\DHONI HANIF\OneDrive\Documents\AI_Collection_and_Loss_Reverse_Forecast\data_preparation\EDA\Univariate_bivariate_multivariate\Bivariate_Analysis\nasabah.ipynb Cell 21 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/DHONI%20HANIF/OneDrive/Documents/AI_Collection_and_Loss_Reverse_Forecast/data_preparation/EDA/Univariate_bivariate_multivariate/Bivariate_Analysis/nasabah.ipynb#X26sZmlsZQ%3D%3D?line=0'>1</a> sns.boxplot(data=df_nasabah, x="debtor_marital_status", y="age")
#
# File c:\Users\DHONI HANIF\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\categorical.py:2231, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2224 def boxplot(
#    2225     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2226     orient=None, color=None, palette=None, saturation=.75, width=.8,
#    2227     dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None,
#    2228     **kwargs
#    2229 ):
# -> 2231     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2232                           orient, color, palette, saturation,
#    2233                           width, dodge, fliersize, linewidth)
#    2235     if ax is None:
#    2236         ax = plt.gca()
#
# File c:\Users\DHONI HANIF\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\categorical.py:785, in _BoxPlotter.__init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     781 def __init__(self, x, y, hue, data, order, hue_order,
#     782              orient, color, palette, saturation,
#     783              width, dodge, fliersize, linewidth):
# --> 785     self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     786     self.establish_colors(color, palette, saturation)
#     788     self.dodge = dodge
#
# File c:\Users\DHONI HANIF\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\categorical.py:541, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     539     if isinstance(var, str):
#     540         err = f"Could not interpret input '{var}'"
# --> 541         raise ValueError(err)
#     543 # Figure out the plotting orientation
#     544 orient = infer_orient(
#     545     x, y, orient, require_numeric=self.require_numeric
#     546 )
#
# ValueError: Could not interpret input 'age'

# %% [markdown]
# Age x Education

# %%
sns.boxplot(data=df_nasabah, x="debtor_education_level", y="age")
# Out:
# <Axes: xlabel='debtor_education_level', ylabel='age'>

# %% [markdown]
# Education x Income

# %%
sns.boxplot(data=df_nasabah, x="debtor_education_level", y="net_income")
# Out:
# <Axes: xlabel='debtor_education_level', ylabel='net_income'>

# %% [markdown]
# Gender x Income

# %%
sns.boxplot(data=df_nasabah, x="debtor_gender", y="net_income")
# Out:
# <Axes: xlabel='debtor_gender', ylabel='net_income'>

# %% [markdown]
# Martial Status x Income

# %%
sns.boxplot(data=df_nasabah, x="debtor_marital_status", y="net_income")
# Out:
# <Axes: xlabel='debtor_martial_status', ylabel='net_income'>

# %%
# for i in range(2000):
#     if df_nasabah.loc[i, "income"] >= 25000000:
#         df_nasabah.loc[i, "martial_status"] = "Belum menikah"

# %%
sns.boxplot(data=df_nasabah, x="debtor_marital_status", y="net_income")
# Out:
# <Axes: xlabel='debtor_martial_status', ylabel='net_income'>

# %% [markdown]
# aging vs net income

# %%
sns.boxplot(data=df_nasabah, x="aging", y="net_income")
# Out:
# <Axes: xlabel='aging', ylabel='net_income'>

# %% [markdown]
# Age x Income

# %%
sns.lineplot(data=df_nasabah, x="debtor_age", y="net_income")
# Out:
# <Axes: xlabel='age', ylabel='net_income'>

# %% [markdown]
# Responsibility x Income

# %%
sns.lineplot(data=df_nasabah, x="number_of_dependents", y="net_income")
# Out:
# <Axes: xlabel='number_of_dependents', ylabel='net_income'>

# %% [markdown]
# Credit aset x Income

# %%
sns.lineplot(data=df_nasabah, x="aset", y="net_income")
# Out:
# <Axes: xlabel='aset', ylabel='net_income'>

# %%
df_nasabah.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   debtor_gender               5000 non-null   category
#  1   age                         5000 non-null   int64
#  2   debtor_education_level      5000 non-null   category
#  3   debtor_martial_status       5000 non-null   category
#  4   employment_type             5000 non-null   category
#  5   number_of_dependents        5000 non-null   int64
#  6   net_income                  5000 non-null   float64
#  7   payment_date                5000 non-null   int64
#  8   loan_amount                 5000 non-null   float64
#  9   avg_amounts_previous_bills  5000 non-null   int64
#  10  avg_previous_payment        5000 non-null   int64
#  11  amount_of_late              5000 non-null   int64
#  12  late_payment_amount         5000 non-null   int64
#  13  credit_risk                 5000 non-null   category
#  14  credit_score                5000 non-null   int64
#  15  arrears_amounts             5000 non-null   int64
#  16  aset                        5000 non-null   int64
#  17  loss_reverse                5000 non-null   float64
#  18  aging                       5000 non-null   category
# dtypes: category(6), float64(3), int64(10)
# memory usage: 538.5 KB

# %% [markdown]
# age x responsibility

# %%
sns.lineplot(data=df_nasabah, x="number_of_dependents", y="age")
# Out:
# <Axes: xlabel='number_of_dependents', ylabel='age'>

# %% [markdown]
# Martial Status x Responsibility

# %%
sns.boxplot(data=df_nasabah, x="debtor_marital_status", y="number_of_dependents")
# Out:
# <Axes: xlabel='debtor_martial_status', ylabel='number_of_dependents'>

# %% [markdown]
# Education x Responsibility

# %%
sns.boxplot(data=df_nasabah, x="debtor_education_level", y="number_of_dependents")
# Out:
# <Axes: xlabel='debtor_education_level', ylabel='number_of_dependents'>

# %% [markdown]
# aging x Responsibility

# %%
sns.boxplot(data=df_nasabah, x="aging", y="number_of_dependents")
# Out:
# <Axes: xlabel='aging', ylabel='number_of_dependents'>

# %%
# for i in range(3000):

# %%
from sklearn.preprocessing import LabelEncoder
# Scaling category variable

columns = {}
for i in df_nasabah.columns:
    if df_nasabah[i].dtype == "category" or df_nasabah[i].dtype == "object":
        columns[i] = LabelEncoder().fit(df_nasabah[i])
        df_nasabah[i] = columns[i].transform(df_nasabah[i])
 
fig, ax = plt.subplots(figsize=(20, 15))
sns.heatmap(data=df_nasabah.corr(), annot=True, linewidths=.2, linecolor="white", cmap="winter", ax=ax)
# Out:
# <Axes: >
