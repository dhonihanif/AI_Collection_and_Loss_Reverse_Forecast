# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_nasabah = pd.read_csv(r"C:\Users\DHONI HANIF\OneDrive\Documents\AI_Collection_and_Loss_Reverse_Forecast\data_preparation\data_clean\nasabah_clean.csv")
df_nasabah.head(5)
# Out:
#    Unnamed: 0 debtor_gender debtor_education_level employment_type  \
# 0           0     perempuan                     D3         Retired
# 1           1     laki-laki                     D3       Full-time
# 2           2     laki-laki                     D2       Full-time
# 3           3     laki-laki                     D2         Retired
# 4           4     laki-laki                    SMA        Contract
#
#    number_of_dependents  net_income payment_date   loan_amount  \
# 0                     3  15500000.0   2023-04-18  6.250000e+07
# 1                     3  17500000.0   2023-08-26  7.083333e+07
# 2                     4  17500000.0   2023-08-03  5.933333e+07
# 3                     3  15500000.0   2023-07-02  6.116667e+07
# 4                     5   8700000.0   2023-09-10  5.616667e+07
#
#    amount_of_late  late_payment_amount  ...  loss_reverse   aging  debtor_zip  \
# 0               2                    1  ...  0.000000e+00     DPK       12188
# 1              31                    3  ...  1.770833e+07     DPK       56126
# 2               0                    0  ...  0.000000e+00  Lancar       98101
# 3              64                    5  ...  1.529167e+07     DPK       76993
# 4              14                    2  ...  0.000000e+00     DPK        6297
#
#    debtor_rt  debtor_rw       debtor_birth_place  debtor_age  \
# 0          6         10     Bengkulu, 23-09-1997          26
# 1         20         20  Jawa Tengah, 13-04-1964          59
# 2          2         15  Jawa Tengah, 01-09-1981          42
# 3         19         16         Aceh, 14-02-1987          36
# 4          1          1    Gorontalo, 06-12-1998          25
#
#    debtor_occupation  debtor_marital_status tenor
# 0          Pengusaha                Menikah    21
# 1          Pengusaha                Menikah    18
# 2              Buruh             Cerai mati    17
# 3          Pengusaha                Menikah    17
# 4     Pegawai Swasta            Cerai hidup    15
#
# [5 rows x 24 columns]

# %%
df_nasabah.drop(["Unnamed: 0"], axis=1, inplace=True)

# %%
df_nasabah.columns
# Out:
# Index(['debtor_gender', 'debtor_education_level', 'employment_type',
#        'number_of_dependents', 'net_income', 'payment_date', 'loan_amount',
#        'amount_of_late', 'late_payment_amount', 'credit_risk', 'credit_score',
#        'arrears_amounts', 'aset', 'loss_reverse', 'aging', 'debtor_zip',
#        'debtor_rt', 'debtor_rw', 'debtor_birth_place', 'debtor_age',
#        'debtor_occupation', 'debtor_marital_status', 'tenor'],
#       dtype='object')

# %%
df_nasabah.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   debtor_gender           5000 non-null   object
#  1   debtor_education_level  5000 non-null   object
#  2   employment_type         5000 non-null   object
#  3   number_of_dependents    5000 non-null   int64
#  4   net_income              5000 non-null   float64
#  5   payment_date            5000 non-null   object
#  6   loan_amount             5000 non-null   float64
#  7   amount_of_late          5000 non-null   int64
#  8   late_payment_amount     5000 non-null   int64
#  9   credit_risk             5000 non-null   object
#  10  credit_score            5000 non-null   int64
#  11  arrears_amounts         5000 non-null   int64
#  12  aset                    5000 non-null   int64
#  13  loss_reverse            5000 non-null   float64
#  14  aging                   5000 non-null   object
#  15  debtor_zip              5000 non-null   int64
#  16  debtor_rt               5000 non-null   int64
#  17  debtor_rw               5000 non-null   int64
#  18  debtor_birth_place      5000 non-null   object
#  19  debtor_age              5000 non-null   int64
#  20  debtor_occupation       5000 non-null   object
#  21  debtor_marital_status   5000 non-null   object
#  22  tenor                   5000 non-null   int64
# dtypes: float64(3), int64(11), object(9)
# memory usage: 898.6+ KB

# %%
# Univariate Analysis for categorical variables of gender
fig, ax = plt.subplots(figsize=(5, 3), layout="constrained")
sns.histplot(data=df_nasabah["debtor_gender"], ax=ax)
ax.set_title("Gender")
plt.show()
print(df_nasabah["debtor_gender"].value_counts())
# Out:
# debtor_gender
# laki-laki    2530
# perempuan    2470
# Name: count, dtype: int64

# %%
# Univariate Analysis for categorical variables of gender
fig, ax = plt.subplots(figsize=(5, 3), layout="constrained")
sns.histplot(data=df_nasabah["debtor_education_level"], ax=ax)
ax.set_title("Education")
plt.show()
print(df_nasabah["debtor_education_level"].value_counts())
# Out:
# debtor_education_level
# S1     1214
# D3     1031
# D1      843
# S2      584
# SMA     553
# D2      418
# S3      201
# SMP     104
# SD       52
# Name: count, dtype: int64

# %%
# Univariate Analysis for categorical variables of gender
fig, ax = plt.subplots(figsize=(5, 3), layout="constrained")
sns.histplot(data=df_nasabah["debtor_marital_status"], ax=ax)
ax.set_title("Marital Status")
plt.show()
print(df_nasabah["debtor_marital_status"].value_counts())
# Out:
# debtor_marital_status
# Cerai hidup      1288
# Menikah          1282
# Cerai mati       1271
# Belum menikah    1159
# Name: count, dtype: int64

# %%
# Univariate Analysis for categorical variables of Credit Risk
fig, ax = plt.subplots(figsize=(10, 3), layout="constrained")
sns.histplot(data=df_nasabah["employment_type"], ax=ax)
ax.set_title("Employed Type")
plt.show()
print(df_nasabah["employment_type"].value_counts())
# Out:
# employment_type
# Retired          2435
# Full-time        1466
# Contract          765
# Not-employed      111
# Part-time          95
# Self-employed      70
# Internship         58
# Name: count, dtype: int64

# %%
# Univariate Analysis for categorical variables of Credit Risk
fig, ax = plt.subplots(figsize=(5, 3), layout="constrained")
sns.histplot(data=df_nasabah["credit_risk"], ax=ax)
ax.set_title("Credit Risk")
plt.show()
print(df_nasabah["credit_risk"].value_counts())
# Out:
# credit_risk
# Tidak tertagih    2775
# Tertagih          2225
# Name: count, dtype: int64

# %%
# Univariate Analysis for categorical variables of aging
fig, ax = plt.subplots(figsize=(6, 3), layout="constrained")
sns.histplot(data=df_nasabah["aging"], ax=ax)
ax.set_title("Aging")
plt.show()
print(df_nasabah["aging"].value_counts())
# Out:
# aging
# DPK              3155
# Diragukan         798
# Kurang lancar     767
# Lancar            216
# Macet              64
# Name: count, dtype: int64

# %%
# Univariate Analysis of datetime variable payment_date
date = pd.to_datetime(df_nasabah["payment_date"]).dt.month
df_nasabah["payment_date"] = date
fig, ax = plt.subplots(figsize=(5, 3), layout="constrained")
sns.histplot(data=date, ax=ax)
ax.set_title("Date")
plt.show()
print(date.value_counts())
# Out:
# payment_date
# 3    616
# 7    596
# 5    589
# 1    585
# 8    561
# 4    556
# 6    548
# 2    548
# 9    401
# Name: count, dtype: int64

# %%
# Univariate Analysis of Numerical variables Age
fig, ax = plt.subplots(1, 2, figsize=(8, 5), layout="constrained")
sns.histplot(data=df_nasabah["debtor_age"], ax=ax[0])
sns.boxplot(data=df_nasabah["debtor_age"], ax=ax[1])
ax[0].set_title("Histplot of Age")
ax[1].set_title("Boxplot of Age")
plt.show()
print(df_nasabah["debtor_age"].describe())
# Out:
# count    5000.000000
# mean       43.127400
# std        11.795279
# min        23.000000
# 25%        33.000000
# 50%        43.000000
# 75%        53.000000
# max        63.000000
# Name: debtor_age, dtype: float64

# %%
# Univariate Analysis of Numerical variables Income
fig, ax = plt.subplots(1, 2, figsize=(8, 5), layout="constrained")
sns.histplot(data=df_nasabah["net_income"], ax=ax[0])
sns.boxplot(data=df_nasabah["net_income"], ax=ax[1])
ax[0].set_title("Histplot of Income")
ax[1].set_title("Boxplot of Income")
plt.show()
print(df_nasabah["net_income"].describe())
# Out:
# count    5.000000e+03
# mean     1.598885e+07
# std      5.932670e+06
# min      2.000000e+05
# 25%      1.150000e+07
# 50%      1.550000e+07
# 75%      1.900000e+07
# max      3.600000e+07
# Name: net_income, dtype: float64

# %%
df_nasabah.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   debtor_gender           5000 non-null   object
#  1   debtor_education_level  5000 non-null   object
#  2   employment_type         5000 non-null   object
#  3   number_of_dependents    5000 non-null   int64
#  4   net_income              5000 non-null   float64
#  5   payment_date            5000 non-null   int32
#  6   loan_amount             5000 non-null   float64
#  7   amount_of_late          5000 non-null   int64
#  8   late_payment_amount     5000 non-null   int64
#  9   credit_risk             5000 non-null   object
#  10  credit_score            5000 non-null   int64
#  11  arrears_amounts         5000 non-null   int64
#  12  aset                    5000 non-null   int64
#  13  loss_reverse            5000 non-null   float64
#  14  aging                   5000 non-null   object
#  15  debtor_zip              5000 non-null   int64
#  16  debtor_rt               5000 non-null   int64
#  17  debtor_rw               5000 non-null   int64
#  18  debtor_birth_place      5000 non-null   object
#  19  debtor_age              5000 non-null   int64
#  20  debtor_occupation       5000 non-null   object
#  21  debtor_marital_status   5000 non-null   object
#  22  tenor                   5000 non-null   int64
# dtypes: float64(3), int32(1), int64(11), object(8)
# memory usage: 879.0+ KB

# %%
# Univariate Analysis of Numerical variables Responsibility
fig, ax = plt.subplots(1, 2, figsize=(8, 5), layout="constrained")
sns.histplot(data=df_nasabah["number_of_dependents"], ax=ax[0])
sns.boxplot(data=df_nasabah["number_of_dependents"], ax=ax[1])
ax[0].set_title("Histplot of Number of Dependents")
ax[1].set_title("Boxplot of Number of Dependents")
plt.show()
print(df_nasabah["number_of_dependents"].describe())
# Out:
# count    5000.000000
# mean        3.086000
# std         1.340509
# min         0.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         7.000000
# Name: number_of_dependents, dtype: float64

# %%
# Univariate Analysis of Numerical variables payment_total
fig, ax = plt.subplots(1, 2, figsize=(8, 5), layout="constrained")
sns.histplot(data=df_nasabah["loan_amount"], ax=ax[0])
sns.boxplot(data=df_nasabah["loan_amount"], ax=ax[1])
ax[0].set_title("Histplot of Loan Amount")
ax[1].set_title("Boxplot of Loan Amount")
plt.show()
print(df_nasabah["loan_amount"].describe())
# Out:
# count    5.000000e+03
# mean     6.559770e+07
# std      2.405757e+07
# min      1.250000e+07
# 25%      5.633333e+07
# 50%      6.050000e+07
# 75%      6.683333e+07
# max      1.716667e+08
# Name: loan_amount, dtype: float64

# %%
from sklearn.preprocessing import RobustScaler

payment_ = RobustScaler().fit_transform(df_nasabah["loan_amount"].to_numpy().reshape(-1, 1))
fig, ax = plt.subplots(1, 2, figsize=(8, 5), layout="constrained")
sns.histplot(data=payment_, ax=ax[0])
sns.boxplot(data=payment_, ax=ax[1])
ax[0].set_title("Histplot of Loan Amount")
ax[1].set_title("Boxplot of Loan Amount")
ax[0].set_xlim(-5, 5)
ax[1].set_ylim(-5, 5)
plt.show()

# %%
# Univariate Analysis of Numerical variables payment_total
fig, ax = plt.subplots(1, 2, figsize=(8, 5), layout="constrained")
sns.histplot(data=df_nasabah["tenor"], ax=ax[0])
sns.boxplot(data=df_nasabah["tenor"], ax=ax[1])
ax[0].set_title("tenor")
ax[1].set_title("tenor")
plt.show()
print(df_nasabah["tenor"].describe())
# Out:
# count    5000.000000
# mean       12.110800
# std         7.595266
# min         1.000000
# 25%         6.000000
# 50%        11.000000
# 75%        17.000000
# max        35.000000
# Name: tenor, dtype: float64

# %%
df_nasabah.columns
# Out:
# Index(['debtor_gender', 'debtor_education_level', 'employment_type',
#        'number_of_dependents', 'net_income', 'payment_date', 'loan_amount',
#        'amount_of_late', 'late_payment_amount', 'credit_risk', 'credit_score',
#        'arrears_amounts', 'aset', 'loss_reverse', 'aging', 'debtor_zip',
#        'debtor_rt', 'debtor_rw', 'debtor_birth_place', 'debtor_age',
#        'debtor_occupation', 'debtor_marital_status', 'tenor'],
#       dtype='object')

# %%
# Univariate Analysis of Numerical variables avg_billing_delay
fig, ax = plt.subplots(1, 2, figsize=(8, 5), constrained_layout=True)
sns.histplot(data=df_nasabah, x="amount_of_late", ax=ax[0])
sns.boxplot(data=df_nasabah, y="amount_of_late", ax=ax[1])
ax[0].set_title("Histplot of Amount of Late")
ax[1].set_title("Histplot of Amount of Late")
plt.show()
print(df_nasabah["amount_of_late"].describe())
# Out:
# count    5000.000000
# mean       69.656600
# std        47.851364
# min         0.000000
# 25%        30.000000
# 50%        62.000000
# 75%       105.000000
# max       246.000000
# Name: amount_of_late, dtype: float64

# %%
# Univariate Analysis of Numerical variables avg_amounts_previous_bills
fig, ax = plt.subplots(1, 2, figsize=(8, 5), constrained_layout=True)
sns.histplot(data=df_nasabah, x="late_payment_amount", ax=ax[0])
sns.boxplot(data=df_nasabah, y="late_payment_amount", ax=ax[1])
ax[0].set_title("late_payment_amount")
ax[1].set_title("late_payment_amount")
plt.show()
print(df_nasabah["late_payment_amount"].describe())
# Out:
# count    5000.000000
# mean        4.494400
# std         2.839785
# min         0.000000
# 25%         2.000000
# 50%         4.000000
# 75%         7.000000
# max        12.000000
# Name: late_payment_amount, dtype: float64

# %%
# Univariate Analysis of Numerical variables avg_amounts_previous_bills
fig, ax = plt.subplots(1, 2, figsize=(8, 5), constrained_layout=True)
sns.histplot(data=df_nasabah, x="credit_score", ax=ax[0])
sns.boxplot(data=df_nasabah, y="credit_score", ax=ax[1])
ax[0].set_title("credit_score")
ax[1].set_title("credit_score")
plt.show()
print(df_nasabah["credit_score"].describe())
# Out:
# count    5000.000000
# mean      335.858000
# std       154.574048
# min         0.000000
# 25%       223.000000
# 50%       322.000000
# 75%       442.000000
# max       901.000000
# Name: credit_score, dtype: float64

# %%
# Univariate Analysis of Numerical variables avg_amounts_previous_bills
fig, ax = plt.subplots(1, 2, figsize=(8, 5), constrained_layout=True)
sns.histplot(data=df_nasabah, x="aset", ax=ax[0])
sns.boxplot(data=df_nasabah, y="aset", ax=ax[1])
ax[0].set_title("Aset")
ax[1].set_title("Aset")
plt.show()
print(df_nasabah["aset"].describe())
# Out:
# count    5.000000e+03
# mean     9.009500e+06
# std      5.398332e+06
# min      5.000000e+05
# 25%      5.500000e+06
# 50%      8.000000e+06
# 75%      1.050000e+07
# max      1.700000e+08
# Name: aset, dtype: float64

# %%
# Univariate Analysis of Numerical variables avg_amounts_previous_bills
fig, ax = plt.subplots(1, 2, figsize=(8, 5), constrained_layout=True)
sns.histplot(data=df_nasabah, x="arrears_amounts", ax=ax[0])
sns.boxplot(data=df_nasabah, y="arrears_amounts", ax=ax[1])
ax[0].set_title("arrears_amounts")
ax[1].set_title("arrears_amounts")
plt.show()
print(df_nasabah["arrears_amounts"].describe())
# Out:
# count    5000.000000
# mean        1.303800
# std         0.936419
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max         8.000000
# Name: arrears_amounts, dtype: float64

# %%
# Univariate Analysis of Numerical variables avg_amounts_previous_bills
fig, ax = plt.subplots(1, 2, figsize=(8, 5), constrained_layout=True)
sns.histplot(data=df_nasabah, x="loss_reverse", ax=ax[0])
sns.boxplot(data=df_nasabah, y="loss_reverse", ax=ax[1])
ax[0].set_title("loss_reverse")
ax[1].set_title("loss_reverse")
plt.show()
print(df_nasabah["loss_reverse"].describe())
# Out:
# count    5.000000e+03
# mean     2.134012e+07
# std      1.821149e+07
# min      0.000000e+00
# 25%      1.358333e+07
# 50%      1.562500e+07
# 75%      3.041667e+07
# max      1.785417e+08
# Name: loss_reverse, dtype: float64

# %%
# Univariate Analysis of Numerical variables avg_amounts_previous_bills
fig, ax = plt.subplots(1, 2, figsize=(8, 5), constrained_layout=True)
scaler = RobustScaler
sns.histplot(data=df_nasabah, x="loss_reverse", ax=ax[0])
sns.boxplot(data=df_nasabah, y="loss_reverse", ax=ax[1])
ax[0].set_title("loss_reverse")
ax[1].set_title("loss_reverse")
plt.show()
print(df_nasabah["loss_reverse"].describe())
# Out:
# count    5.000000e+03
# mean     2.134012e+07
# std      1.821149e+07
# min      0.000000e+00
# 25%      1.358333e+07
# 50%      1.562500e+07
# 75%      3.041667e+07
# max      1.785417e+08
# Name: loss_reverse, dtype: float64

# %%
df_nasabah.to_csv("new_nasabah.csv")
