# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler, LabelEncoder
from sklearn.ensemble import AdaBoostRegressor, RandomForestRegressor, BaggingRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from lazypredict.Supervised import LazyRegressor

# %%
df = pd.read_csv(r"C:\Users\DHONI HANIF\OneDrive\Documents\AI_Collection_and_Loss_Reverse_Forecast\data_preparation\EDA\Univariate_bivariate_multivariate\Univariate_Analysis\new_kolektor.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                1000 non-null   int64
#  1   time_to_collect           1000 non-null   int64
#  2   avg_bill_methods          1000 non-null   object
#  3   debtor_volume_handled     1000 non-null   int64
#  4   bill_amount_collected     1000 non-null   int64
#  5   total_actual              1000 non-null   int64
#  6   total_cost                1000 non-null   int64
#  7   success_rate              1000 non-null   float64
#  8   collector_age             1000 non-null   int64
#  9   collector_marital_status  1000 non-null   object
#  10  collector_gender          1000 non-null   object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 86.1+ KB

# %%
for i in df.columns:
    if df[i].dtype == "object":
        df[i] = df[i].astype("category")

df.drop(["Unnamed: 0"], axis=1, inplace=True)

# %%
df.head()
# Out:
#    time_to_collect  avg_bill_methods  debtor_volume_handled  \
# 0                0         sms or WA                      7
# 1               11         panggilan                     35
# 2                4         sms or WA                      6
# 3               29  datang ke tempat                     63
# 4               22  datang ke tempat                     35
#
#    bill_amount_collected  total_actual  total_cost  success_rate  \
# 0               14400000      35700000      277706         40.00
# 1               79000000     160500000    22382611         49.00
# 2                7100000      26700000      205389         27.00
# 3              782000000    1395000000   482942548         56.00
# 4              346000000     485500000   151035603         71.00
#
#    collector_age collector_marital_status collector_gender
# 0             45                  Menikah        laki-laki
# 1             32               Cerai mati        perempuan
# 2             62              Cerai hidup        laki-laki
# 3             55               Cerai mati        perempuan
# 4             53                  Menikah        perempuan

# %%
df["avg_bill_methods"].value_counts()
# Out:
# avg_bill_methods
# datang ke tempat    481
# sms or WA           198
# panggilan           162
# surat panggilan     159
# Name: count, dtype: int64

# %%
bill_methods = LabelEncoder().fit(df["avg_bill_methods"].to_numpy().reshape(-1, 1))
gender = LabelEncoder().fit(df["collector_gender"].to_numpy().reshape(-1, 1))
mart = LabelEncoder().fit(df["collector_marital_status"].to_numpy().reshape(-1, 1))
df2 = pd.DataFrame()

df2["avg_bill_methods"] = bill_methods.transform(df["avg_bill_methods"])
df2["collector_gender"] = gender.transform(df["collector_gender"])
df2["collector_marital_status"] = mart.transform(df["collector_marital_status"])
           
scaler = RobustScaler().fit(df[["bill_amount_collected", "total_actual", "total_cost"]])
df2[["bill_amount_collected", "total_actual", "total_cost"]] = scaler.transform(df[["bill_amount_collected", "total_actual", "total_cost"]])
df2[["debtor_volume_handled", "collector_age", "success_rate"]] = df[["debtor_volume_handled", "collector_age", "success_rate"]]
y = df["time_to_collect"]

df2.head(5)
# Out:
#    avg_bill_methods  collector_gender  collector_marital_status  \
# 0                 2                 0                         3
# 1                 1                 1                         2
# 2                 2                 0                         1
# 3                 0                 1                         2
# 4                 0                 1                         3
#
#    bill_amount_collected  total_actual  total_cost  debtor_volume_handled  \
# 0                  -0.46         -0.52       -0.25                      7
# 1                  -0.28         -0.34       -0.16                     35
# 2                  -0.48         -0.53       -0.25                      6
# 3                   1.64          1.39        1.72                     63
# 4                   0.45          0.11        0.36                     35
#
#    collector_age  success_rate
# 0             45         40.00
# 1             32         49.00
# 2             62         27.00
# 3             55         56.00
# 4             53         71.00

# %%
X = df2

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42)
reg = LazyRegressor(verbose=0, ignore_warnings=True)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)
models
# Out:
#  12%|█▏        | 5/42 [00:00<00:04,  7.99it/s]
# 100%|██████████| 42/42 [00:07<00:00,  5.59it/s]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000238 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 984
# [LightGBM] [Info] Number of data points in the train set: 800, number of used features: 9
# [LightGBM] [Info] Start training from score 14.565000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# AdaBoostRegressor                            0.87       0.88  2.97        0.22
# GradientBoostingRegressor                    0.86       0.87  3.09        0.60
# RandomForestRegressor                        0.86       0.87  3.11        1.59
# ExtraTreesRegressor                          0.86       0.87  3.13        0.81
# BaggingRegressor                             0.85       0.85  3.26        0.29
# XGBRegressor                                 0.85       0.85  3.27        0.21
# LGBMRegressor                                0.84       0.85  3.33        0.20
# HistGradientBoostingRegressor                0.84       0.84  3.38        0.91
# KNeighborsRegressor                          0.83       0.84  3.44        0.02
# NuSVR                                        0.83       0.84  3.47        0.06
# MLPRegressor                                 0.83       0.83  3.49        0.90
# SVR                                          0.82       0.83  3.51        0.08
# ExtraTreeRegressor                           0.78       0.79  3.90        0.03
# ElasticNetCV                                 0.78       0.79  3.94        0.47
# LarsCV                                       0.78       0.79  3.95        0.05
# LassoLarsCV                                  0.78       0.79  3.95        0.02
# LassoCV                                      0.78       0.79  3.95        0.13
# LassoLarsIC                                  0.77       0.79  3.96        0.01
# RidgeCV                                      0.77       0.78  3.96        0.01
# HuberRegressor                               0.77       0.78  3.97        0.03
# BayesianRidge                                0.77       0.78  3.98        0.15
# SGDRegressor                                 0.77       0.78  3.98        0.02
# Ridge                                        0.77       0.78  3.99        0.02
# Lars                                         0.77       0.78  3.99        0.02
# LinearRegression                             0.77       0.78  3.99        0.02
# TransformedTargetRegressor                   0.77       0.78  3.99        0.01
# LassoLars                                    0.77       0.78  4.00        0.02
# Lasso                                        0.77       0.78  4.00        0.02
# LinearSVR                                    0.77       0.78  4.00        0.02
# OrthogonalMatchingPursuitCV                  0.77       0.78  4.02        0.02
# RANSACRegressor                              0.76       0.77  4.07        0.10
# ElasticNet                                   0.76       0.77  4.09        0.03
# PoissonRegressor                             0.75       0.76  4.17        0.02
# DecisionTreeRegressor                        0.74       0.76  4.22        0.09
# TweedieRegressor                             0.74       0.75  4.23        0.01
# OrthogonalMatchingPursuit                    0.69       0.70  4.64        0.02
# PassiveAggressiveRegressor                   0.59       0.61  5.32        0.01
# GaussianProcessRegressor                     0.52       0.55  5.75        0.13
# DummyRegressor                              -0.05      -0.00  8.55        0.03
# KernelRidge                                 -2.25      -2.11 15.04        0.05

# %%
def evaluate_performa(X_test, y_test, model1, model2, model3, model4, model5):
    rate = [0, 0, 0, 0, 0]
    #difference = [0, 0, 0, 0, 0]

    X_test = X_test.reset_index(drop=True)
    for i, _ in X_test.iterrows():
        X = np.array(X_test.iloc[[i]])
        y = np.array(y_test.iloc[[i]])
        difference = [0, 0, 0, 0, 0]
        difference[0] = abs(model1.predict(X) - y[0])
        difference[1] = abs(model2.predict(X) - y[0])
        difference[2] = abs(model3.predict(X) - y[0])
        difference[3] = abs(model4.predict(X) - y[0])
        difference[4] = abs(model5.predict(X) - y[0])
        print(difference)

        a = int(np.argmin(difference))
        print(a)
        for i in range(len(difference)):
            if difference[a] == difference[i]:
                rate[i] += 1
    
    a = f"Best model : {rate.index(max(rate))+1}"
    return a, rate

# %%
extra = ExtraTreesRegressor()
forest = RandomForestRegressor()
ada = AdaBoostRegressor()
gradient = GradientBoostingRegressor()
bagging = BaggingRegressor()

extra.fit(X_train, y_train)
forest.fit(X_train, y_train)
ada.fit(X_train, y_train)
gradient.fit(X_train, y_train)
bagging.fit(X_train, y_train)

a = evaluate_performa(X_test, y_test, extra, forest, gradient, bagging, ada)
a
# Out:
# [array([3.1]), array([3.7]), array([2.82187853]), array([3.]), array([3.31564246])]
# 2
# [array([8.37]), array([7.41]), array([7.64720435]), array([7.1]), array([6.82012195])]
# 4
# [array([2.58]), array([2.26]), array([2.38621604]), array([1.4]), array([2.46099291])]
# 3
# [array([1.59]), array([1.6]), array([0.64123183]), array([1.1]), array([1.41772152])]
# 2
# [array([2.54]), array([2.41]), array([1.95281579]), array([2.9]), array([2.13432836])]
# 2
# [array([7.83]), array([7.12]), array([6.88444]), array([7.7]), array([6.68435754])]
# 4
# [array([1.83]), array([1.84]), array([1.97930781]), array([2.9]), array([2.08108108])]
# 0
# [array([1.1]), array([1.]), array([0.55668441]), array([1.2]), array([0.86567164])]
# 2
# [array([0.5]), array([0.1]), array([1.86375113]), array([1.3]), array([0.45355191])]
# 1
# [array([3.22]), array([2.81]), array([2.63975143]), array([2.2]), array([2.88235294])]
# 3
# [array([0.1]), array([0.34]), array([0.05498302]), array([1.1]), array([0.41772152])]
# 2
# [array([0.03]), array([0.23]), array([1.07299612]), array([0.5]), array([1.08108108])]
# 0
# [array([1.91]), array([2.44]), array([1.9101665]), array([4.]), array([0.72033898])]
# 4
# [array([0.68]), array([1.29]), array([0.38080925]), array([0.8]), array([0.45819398])]
# 2
# [array([2.43]), array([4.23]), array([3.8091276]), array([4.4]), array([3.53358209])]
# 0
# [array([6.55]), array([6.18]), array([7.48457106]), array([6.6]), array([5.95636364])]
# 4
# [array([2.72]), array([2.22]), array([1.29775589]), array([2.1]), array([1.08108108])]
# 4
# [array([5.33]), array([6.76]), array([6.94539641]), array([5.4]), array([7.51298701])]
# 0
# [array([0.86]), array([0.83]), array([0.77848179]), array([1.5]), array([0.71544715])]
# 4
# [array([1.89]), array([1.69]), array([1.4363647]), array([1.1]), array([1.86567164])]
# 3
# [array([3.19]), array([1.69]), array([2.66297807]), array([1.8]), array([2.41772152])]
# 1
# [array([6.83]), array([7.58]), array([6.37156186]), array([6.3]), array([5.72033898])]
# 4
# [array([3.05]), array([3.39]), array([3.48784328]), array([2.1]), array([3.78175896])]
# 3
# [array([3.47]), array([4.1]), array([4.13691665]), array([6.4]), array([6.14893617])]
# 0
# [array([3.29]), array([2.63]), array([2.52435997]), array([2.]), array([2.46099291])]
# 3
# [array([5.69]), array([7.18]), array([5.9842103]), array([7.]), array([4.82012195])]
# 4
# [array([0.59]), array([1.31]), array([4.80267368]), array([1.6]), array([0.11111111])]
# 4
# [array([2.75]), array([2.75]), array([3.53231731]), array([3.7]), array([1.54644809])]
# 4
# [array([1.59]), array([1.49]), array([0.82444637]), array([1.6]), array([0.91891892])]
# 2
# [array([1.02]), array([0.11]), array([0.78540274]), array([0.8]), array([0.78651685])]
# 1
# [array([2.6]), array([2.69]), array([1.73623256]), array([1.4]), array([1.85106383])]
# 3
# [array([3.86]), array([5.31]), array([6.18216818]), array([4.2]), array([5.45355191])]
# 0
# [array([0.97]), array([0.06]), array([0.49600004]), array([0.5]), array([0.78651685])]
# 1
# [array([0.29]), array([0.01]), array([0.25318384]), array([0.4]), array([0.13432836])]
# 1
# [array([1.16]), array([1.59]), array([0.80592411]), array([2.]), array([1.13432836])]
# 2
# [array([3.68]), array([2.81]), array([2.11934779]), array([3.8]), array([1.78175896])]
# 4
# [array([6.78]), array([6.77]), array([6.47627925]), array([4.1]), array([6.82012195])]
# 3
# [array([2.36]), array([2.19]), array([1.85985197]), array([1.3]), array([2.13432836])]
# 3
# [array([0.91]), array([0.42]), array([0.22555122]), array([1.]), array([0.11764706])]
# 4
# [array([1.3]), array([1.33]), array([0.41189873]), array([1.2]), array([0.86567164])]
# 2
# [array([1.37]), array([1.17]), array([1.35776759]), array([1.1]), array([0.86567164])]
# 4
# [array([1.87]), array([1.62]), array([1.87888917]), array([1.6]), array([1.90625])]
# 3
# [array([0.6]), array([0.37]), array([0.18893933]), array([0.6]), array([1.04363636])]
# 2
# [array([0.7]), array([0.68]), array([0.30692561]), array([3.2]), array([1.45819398])]
# 2
# [array([2.37]), array([0.26]), array([0.59374536]), array([1.2]), array([1.27142857])]
# 1
# [array([3.81]), array([3.79]), array([3.1092036]), array([3.4]), array([2.46099291])]
# 4
# [array([3.65]), array([4.54]), array([6.1628465]), array([4.2]), array([4.54644809])]
# 0
# [array([6.44]), array([5.72]), array([5.09971256]), array([5.4]), array([4.6344086])]
# 4
# [array([4.46]), array([4.75]), array([3.53608083]), array([2.3]), array([5.21824104])]
# 3
# [array([4.84]), array([5.96]), array([8.90176545]), array([5.7]), array([7.13424658])]
# 0
# [array([1.81]), array([1.2]), array([1.37231095]), array([1.3]), array([0.58227848])]
# 4
# [array([1.72]), array([1.78]), array([2.07125193]), array([1.7]), array([2.13432836])]
# 3
# [array([1.34]), array([0.13]), array([1.24486046]), array([1.5]), array([0.17987805])]
# 1
# [array([0.85]), array([0.62]), array([1.97266633]), array([0.5]), array([0.32])]
# 4
# [array([2.13]), array([1.91]), array([1.93157463]), array([1.6]), array([2.79365079])]
# 3
# [array([1.5]), array([1.65]), array([0.81398761]), array([1.7]), array([0.91891892])]
# 2
# [array([0.89]), array([0.49]), array([0.0689691]), array([0.7]), array([0.09375])]
# 2
# [array([0.1]), array([0.73]), array([0.43934157]), array([0.1]), array([0.21824104])]
# 0
# [array([1.9]), array([1.59]), array([1.54968129]), array([1.5]), array([1.53900709])]
# 3
# [array([3.4]), array([2.48]), array([2.82212044]), array([2.6]), array([1.82012195])]
# 4
# [array([7.86]), array([7.66]), array([7.71123655]), array([7.4]), array([7.11111111])]
# 4
# [array([1.61]), array([1.23]), array([0.97477278]), array([1.6]), array([1.39393939])]
# 2
# [array([0.07]), array([0.43]), array([0.22447063]), array([1.]), array([0.58227848])]
# 0
# [array([7.67]), array([5.8]), array([5.25204152]), array([6.2]), array([4.6049896])]
# 4
# [array([4.38]), array([3.78]), array([3.15948338]), array([4.1]), array([3.27966102])]
# 2
# [array([1.83]), array([1.37]), array([1.4507132]), array([2.4]), array([2.3950104])]
# 1
# [array([2.5]), array([2.17]), array([2.06038885]), array([0.9]), array([2.58227848])]
# 3
# [array([0.02]), array([0.73]), array([0.45393592]), array([0.2]), array([0.60606061])]
# 0
# [array([5.6]), array([5.88]), array([5.16716308]), array([6.3]), array([5.92307692])]
# 2
# [array([1.19]), array([1.67]), array([1.72310154]), array([1.]), array([2.11111111])]
# 3
# [array([2.04]), array([2.17]), array([1.4417732]), array([1.7]), array([1.53900709])]
# 2
# [array([1.98]), array([2.19]), array([1.42547357]), array([1.6]), array([1.39393939])]
# 4
# [array([4.86]), array([2.91]), array([1.05560738]), array([4.8]), array([5.31564246])]
# 2
# [array([0.34]), array([0.29]), array([1.04673992]), array([0.8]), array([0.86567164])]
# 1
# [array([2.23]), array([2.41]), array([2.3154084]), array([2.7]), array([2.13432836])]
# 4
# [array([2.44]), array([2.17]), array([2.17002475]), array([1.5]), array([1.86567164])]
# 3
# [array([3.18]), array([4.12]), array([2.92888126]), array([4.1]), array([2.78175896])]
# 4
# [array([2.07]), array([1.69]), array([1.86816268]), array([1.5]), array([1.91891892])]
# 3
# [array([0.44]), array([0.14]), array([0.3967158]), array([0.1]), array([0.46099291])]
# 3
# [array([0.87]), array([0.24]), array([0.05788876]), array([1.9]), array([0.54644809])]
# 2
# [array([2.93]), array([2.74]), array([2.4927732]), array([1.1]), array([4.17987805])]
# 3
# [array([1.]), array([0.81]), array([1.00484186]), array([1.4]), array([0.86567164])]
# 1
# [array([0.04]), array([0.55]), array([0.42809538]), array([0.3]), array([0.13432836])]
# 0
# [array([2.29]), array([2.15]), array([1.5594426]), array([2.6]), array([0.58227848])]
# 4
# [array([0.24]), array([0.25]), array([1.50237565]), array([1.5]), array([0.54180602])]
# 0
# [array([2.39]), array([2.61]), array([2.40629089]), array([3.]), array([4.07692308])]
# 0
# [array([0.57]), array([0.37]), array([0.22954113]), array([0.]), array([0.13432836])]
# 3
# [array([1.68]), array([2.11]), array([2.27058811]), array([1.7]), array([1.86567164])]
# 0
# [array([1.93]), array([1.13]), array([1.94675426]), array([2.1]), array([1.63343109])]
# 1
# [array([0.79]), array([1.47]), array([1.11662498]), array([2.6]), array([2.07692308])]
# 0
# [array([1.73]), array([1.97]), array([3.3977439]), array([1.2]), array([1.91891892])]
# 3
# [array([5.81]), array([5.54]), array([5.9688055]), array([6.8]), array([5.71544715])]
# 1
# [array([0.91]), array([1.07]), array([1.44226078]), array([0.4]), array([1.39393939])]
# 3
# [array([1.15]), array([1.45]), array([1.8732625]), array([1.7]), array([1.91891892])]
# 0
# [array([3.57]), array([2.38]), array([0.74747998]), array([5.9]), array([2.78175896])]
# 2
# [array([5.77]), array([6.28]), array([6.37250035]), array([7.4]), array([6.21824104])]
# 0
# [array([3.59]), array([2.32]), array([2.12277338]), array([4.]), array([2.82012195])]
# 2
# [array([0.42]), array([0.34]), array([1.15667659]), array([1.5]), array([1.27966102])]
# 1
# [array([2.18]), array([2.18]), array([2.16639948]), array([2.3]), array([2.53900709])]
# 2
# [array([2.]), array([2.95]), array([2.87369211]), array([2.7]), array([2.79365079])]
# 0
# [array([0.54]), array([0.63]), array([0.57090902]), array([0.3]), array([0.39393939])]
# 3
# [array([1.49]), array([0.32]), array([0.31358854]), array([1.6]), array([0.21824104])]
# 4
# [array([0.44]), array([0.03]), array([0.29627916]), array([0.3]), array([0.41772152])]
# 1
# [array([1.74]), array([1.41]), array([2.83547897]), array([1.3]), array([1.91891892])]
# 3
# [array([2.]), array([2.13]), array([1.89533418]), array([1.6]), array([2.13432836])]
# 3
# [array([4.55]), array([5.32]), array([4.02905373]), array([5.4]), array([6.21794872])]
# 2
# [array([0.25]), array([0.15]), array([0.01414089]), array([0.7]), array([0.13432836])]
# 2
# [array([5.57]), array([4.64]), array([3.77539924]), array([3.5]), array([4.07692308])]
# 3
# [array([0.01]), array([0.13]), array([0.34193654]), array([0.3]), array([0.53900709])]
# 0
# [array([0.95]), array([2.11]), array([2.2614238]), array([2.4]), array([0.92307692])]
# 4
# [array([8.3]), array([6.94]), array([6.02277477]), array([6.9]), array([5.95636364])]
# 4
# [array([0.35]), array([1.44]), array([0.77412412]), array([4.3]), array([1.68435754])]
# 0
# [array([2.32]), array([2.25]), array([2.48268217]), array([1.9]), array([2.58227848])]
# 3
# [array([4.46]), array([5.97]), array([6.81639038]), array([5.2]), array([5.3950104])]
# 0
# [array([3.]), array([3.13]), array([3.02455581]), array([2.4]), array([2.88888889])]
# 3
# [array([1.59]), array([1.84]), array([1.02006969]), array([1.1]), array([1.58227848])]
# 2
# [array([0.66]), array([0.34]), array([0.79812844]), array([1.1]), array([1.17987805])]
# 1
# [array([0.83]), array([0.57]), array([1.2346006]), array([0.6]), array([1.91891892])]
# 1
# [array([1.66]), array([1.92]), array([2.06145019]), array([1.4]), array([2.09375])]
# 3
# [array([4.57]), array([5.73]), array([4.98369186]), array([5.6]), array([4.17987805])]
# 4
# [array([1.28]), array([1.03]), array([1.61126396]), array([1.6]), array([1.86567164])]
# 1
# [array([3.02]), array([4.13]), array([6.02279551]), array([3.2]), array([4.11111111])]
# 0
# [array([2.74]), array([2.61]), array([2.27495359]), array([3.4]), array([2.08108108])]
# 4
# [array([1.15]), array([1.53]), array([0.87726229]), array([1.7]), array([0.91891892])]
# 2
# [array([1.63]), array([2.23]), array([2.45293446]), array([2.4]), array([1.91891892])]
# 0
# [array([8.2]), array([6.19]), array([5.66800427]), array([7.4]), array([6.54644809])]
# 2
# [array([0.08]), array([0.38]), array([0.26168574]), array([0.1]), array([0.13432836])]
# 0
# [array([6.05]), array([6.23]), array([5.65925618]), array([8.]), array([5.54180602])]
# 4
# [array([0.82]), array([0.22]), array([0.68081465]), array([1.3]), array([0.58227848])]
# 1
# [array([2.37]), array([3.15]), array([4.47196855]), array([4.8]), array([5.78175896])]
# 0
# [array([1.48]), array([1.11]), array([0.4941315]), array([0.1]), array([1.78175896])]
# 3
# [array([0.36]), array([0.68]), array([0.2512487]), array([1.2]), array([0.13432836])]
# 4
# [array([2.91]), array([2.47]), array([0.93476972]), array([1.5]), array([0.92307692])]
# 4
# [array([0.44]), array([1.06]), array([3.57683357]), array([2.5]), array([4.31564246])]
# 0
# ('Best model : 5', [43, 25, 38, 45, 50])
