# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
from lazypredict.Supervised import LazyRegressor

# %%
df = pd.read_csv(r"C:\Users\DHONI HANIF\OneDrive\Documents\AI Collection and Loss Reverse Forecast\data_preparation\EDA\Univariate_bivariate_multivariate\Univariate_Analysis\new_kolektor.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             1000 non-null   int64
#  1   time_to_collect        1000 non-null   int64
#  2   avg_bill_methods       1000 non-null   object
#  3   debtor_volume_handled  1000 non-null   int64
#  4   bill_amount_collected  1000 non-null   int64
#  5   total_actual           1000 non-null   int64
#  6   total_cost             1000 non-null   int64
#  7   success_rate           1000 non-null   float64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 62.6+ KB

# %%
for i in df.columns:
    if df[i].dtype == "object":
        df[i] = df[i].astype("category")

df.drop(["Unnamed: 0"], axis=1, inplace=True)

# %%
df.head()
# Out:
#    time_to_collect  avg_bill_methods  debtor_volume_handled  \
# 0                0         sms or WA                      7
# 1               11         panggilan                     35
# 2                4         sms or WA                      6
# 3               29  datang ke tempat                     63
# 4               22  datang ke tempat                     35
#
#    bill_amount_collected  total_actual  total_cost  success_rate
# 0               14400000      35700000      277706         40.00
# 1               79000000     160500000    22382611         49.00
# 2                7100000      26700000      205389         27.00
# 3              782000000    1395000000   482942548         56.00
# 4              346000000     485500000   151035603         71.00

# %%
df["avg_bill_methods"].value_counts()
# Out:
# avg_bill_methods
# datang ke tempat    481
# sms or WA           198
# panggilan           162
# surat panggilan     159
# Name: count, dtype: int64

# %%
bill_methods = {"sms or WA": 0, "surat panggilan": 1, "panggilan": 2, "datang ke tempat": 3}
columns = {"avg_bill_methods": bill_methods}
for i in df.columns:
    if df[i].dtype == "category" or df[i].dtype == "object":
        df[i] = [columns[i][j] for j in df[i]]

y = df["time_to_collect"]
df.drop("time_to_collect", axis=1, inplace=True)             
scaler = RobustScaler().fit(df[[i for i in df.columns if i not in columns]])
df2 = pd.DataFrame(scaler.transform(df[[i for i in df.columns if i not in columns]]), columns=df[[i for i in df.columns if i not in columns]].columns)
for i in columns:
    df2[i] = df[i]
df2.head(5)
# Out:
#    debtor_volume_handled  bill_amount_collected  total_actual  total_cost  \
# 0                  -1.35                  -0.46         -0.52       -0.25
# 1                  -0.13                  -0.28         -0.34       -0.16
# 2                  -1.39                  -0.48         -0.53       -0.25
# 3                   1.09                   1.64          1.39        1.72
# 4                  -0.13                   0.45          0.11        0.36
#
#    success_rate  avg_bill_methods
# 0         -0.36                 0
# 1         -0.16                 2
# 2         -0.66                 0
# 3          0.00                 3
# 4          0.34                 3

# %%
X = df2

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42)
reg = LazyRegressor(verbose=0, ignore_warnings=True)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)
models
# Out:
#  98%|█████████▊| 41/42 [07:14<00:00,  1.42it/s]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002406 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 934
# [LightGBM] [Info] Number of data points in the train set: 800, number of used features: 6
# [LightGBM] [Info] Start training from score 14.565000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 100%|██████████| 42/42 [07:16<00:00, 10.40s/it]
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# AdaBoostRegressor                            0.87       0.87  3.05        0.18
# ElasticNetCV                                 0.87       0.87  3.07        0.70
# LassoCV                                      0.87       0.87  3.07        0.48
# LarsCV                                       0.87       0.87  3.07        0.09
# LassoLarsCV                                  0.87       0.87  3.07        0.12
# ExtraTreesRegressor                          0.87       0.87  3.08        1.68
# Ridge                                        0.87       0.87  3.08        0.04
# RidgeCV                                      0.87       0.87  3.08        0.03
# BayesianRidge                                0.87       0.87  3.08        0.05
# LassoLarsIC                                  0.87       0.87  3.08        0.08
# LinearRegression                             0.87       0.87  3.08        0.04
# TransformedTargetRegressor                   0.87       0.87  3.08        0.04
# Lars                                         0.87       0.87  3.08        0.07
# OrthogonalMatchingPursuitCV                  0.87       0.87  3.08        0.07
# SGDRegressor                                 0.87       0.87  3.08        0.04
# LinearSVR                                    0.86       0.87  3.11        0.05
# HuberRegressor                               0.86       0.87  3.12        0.10
# MLPRegressor                                 0.86       0.87  3.13        2.85
# OrthogonalMatchingPursuit                    0.86       0.87  3.13        0.05
# RandomForestRegressor                        0.86       0.86  3.14        3.09
# GradientBoostingRegressor                    0.86       0.86  3.17        1.88
# Lasso                                        0.86       0.86  3.20        0.05
# LassoLars                                    0.86       0.86  3.20        0.06
# PoissonRegressor                             0.85       0.86  3.21        0.05
# SVR                                          0.85       0.86  3.23        0.25
# LGBMRegressor                                0.85       0.86  3.23        1.82
# NuSVR                                        0.85       0.85  3.27        0.27
# HistGradientBoostingRegressor                0.84       0.85  3.33      418.83
# KNeighborsRegressor                          0.84       0.85  3.33        0.07
# BaggingRegressor                             0.84       0.84  3.36        0.74
# XGBRegressor                                 0.84       0.84  3.41        0.46
# RANSACRegressor                              0.83       0.84  3.43        0.11
# ElasticNet                                   0.81       0.81  3.70        0.10
# TweedieRegressor                             0.78       0.79  3.95        0.07
# ExtraTreeRegressor                           0.76       0.76  4.14        0.06
# DecisionTreeRegressor                        0.74       0.75  4.25        0.14
# PassiveAggressiveRegressor                   0.69       0.70  4.65        0.04
# DummyRegressor                              -0.03      -0.00  8.55        0.03
# KernelRidge                                 -2.20      -2.10 15.03        0.26
# GaussianProcessRegressor                  -106.42    -103.18 87.13        1.34
