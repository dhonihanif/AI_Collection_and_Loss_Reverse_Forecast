# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler, LabelEncoder
from sklearn.ensemble import AdaBoostRegressor, RandomForestRegressor, ExtraTreesRegressor, BaggingRegressor, GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from lazypredict.Supervised import LazyRegressor

# %%
df = pd.read_csv(r"C:\Users\DHONI HANIF\OneDrive\Documents\AI_Collection_and_Loss_Reverse_Forecast\modelling\kolektor\regresi_for_total_cost\data\data2.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                1000 non-null   int64
#  1   avg_bill_methods          1000 non-null   object
#  2   debtor_volume_handled     1000 non-null   int64
#  3   bill_amount_collected     1000 non-null   int64
#  4   total_actual              1000 non-null   int64
#  5   total_cost                1000 non-null   int64
#  6   success_rate              1000 non-null   float64
#  7   time_to_collect           1000 non-null   int64
#  8   collector_gender          1000 non-null   object
#  9   collector_marital_status  1000 non-null   object
#  10  collector_age             1000 non-null   int64
# dtypes: float64(1), int64(7), object(3)
# memory usage: 86.1+ KB

# %%
for i in df.columns:
    if df[i].dtype == "object":
        df[i] = df[i].astype("category")

df.drop(["Unnamed: 0"], axis=1, inplace=True)

# %%
df.head()
# Out:
#   avg_bill_methods  debtor_volume_handled  bill_amount_collected  \
# 0        sms or WA                     13               46800000
# 1        sms or WA                     10               52400000
# 2        sms or WA                     13               21300000
# 3        sms or WA                     12               47600000
# 4        sms or WA                     19               16700000
#
#    total_actual  total_cost  success_rate  time_to_collect collector_gender  \
# 0     123100000       99948         38.00                1        laki-laki
# 1      58300000       72633         90.00                1        perempuan
# 2     127900000       79992         17.00                2        laki-laki
# 3      78400000       83538         61.00                1        perempuan
# 4      31600000      133245         53.00                0        perempuan
#
#   collector_marital_status  collector_age
# 0                  Menikah             45
# 1               Cerai mati             32
# 2              Cerai hidup             62
# 3               Cerai mati             55
# 4                  Menikah             53

# %%
df["avg_bill_methods"].value_counts()
# Out:
# avg_bill_methods
# sms or WA           300
# panggilan           250
# surat panggilan     250
# datang ke tempat    200
# Name: count, dtype: int64

# %%
bill_methods = LabelEncoder().fit(df["avg_bill_methods"].to_numpy().reshape(-1, 1))
gender = LabelEncoder().fit(df["collector_gender"].to_numpy().reshape(-1, 1))
mart = LabelEncoder().fit(df["collector_marital_status"].to_numpy().reshape(-1, 1))
df2 = pd.DataFrame()

df2["avg_bill_methods"] = bill_methods.transform(df["avg_bill_methods"])
df2["collector_gender"] = gender.transform(df["collector_gender"])
df2["collector_marital_status"] = mart.transform(df["collector_marital_status"])
           
scaler = RobustScaler().fit(df[["bill_amount_collected", "total_actual", "total_cost"]])
df2[["bill_amount_collected", "total_actual", "total_cost"]] = scaler.transform(df[["bill_amount_collected", "total_actual", "total_cost"]])
df2[["debtor_volume_handled", "collector_age", "success_rate"]] = df[["debtor_volume_handled", "collector_age", "success_rate"]]
y = df["time_to_collect"]

df2.head(5)
# Out:
#    avg_bill_methods  collector_gender  collector_marital_status  \
# 0                 2                 0                         3
# 1                 2                 1                         2
# 2                 2                 0                         1
# 3                 2                 1                         2
# 4                 2                 1                         3
#
#    bill_amount_collected  total_actual  total_cost  debtor_volume_handled  \
# 0                  -0.25         -0.26       -0.34                     13
# 1                  -0.22         -0.40       -0.36                     10
# 2                  -0.35         -0.25       -0.35                     13
# 3                  -0.24         -0.36       -0.35                     12
# 4                  -0.37         -0.46       -0.31                     19
#
#    collector_age  success_rate
# 0             45         38.00
# 1             32         90.00
# 2             62         17.00
# 3             55         61.00
# 4             53         53.00

# %%
X = df2

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42)
reg = LazyRegressor(verbose=0, ignore_warnings=True)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)
models
# Out:
#   5%|▍         | 2/42 [00:00<00:09,  4.35it/s]
# 100%|██████████| 42/42 [00:10<00:00,  3.92it/s]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001277 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 973
# [LightGBM] [Info] Number of data points in the train set: 800, number of used features: 9
# [LightGBM] [Info] Start training from score 8.058750
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# AdaBoostRegressor                            0.93       0.93  1.24        0.24
# RandomForestRegressor                        0.92       0.92  1.29        1.98
# GradientBoostingRegressor                    0.92       0.92  1.32        0.70
# KNeighborsRegressor                          0.92       0.92  1.33        0.03
# ExtraTreesRegressor                          0.91       0.92  1.33        2.02
# BaggingRegressor                             0.91       0.91  1.38        0.22
# HistGradientBoostingRegressor                0.91       0.91  1.40        1.62
# LGBMRegressor                                0.90       0.91  1.41        0.22
# XGBRegressor                                 0.89       0.90  1.51        0.28
# NuSVR                                        0.87       0.88  1.65        0.10
# SVR                                          0.87       0.88  1.65        0.11
# ExtraTreeRegressor                           0.86       0.87  1.70        0.04
# MLPRegressor                                 0.85       0.86  1.77        1.46
# DecisionTreeRegressor                        0.85       0.85  1.79        0.06
# RANSACRegressor                              0.78       0.79  2.15        0.16
# HuberRegressor                               0.77       0.78  2.17        0.06
# LassoLarsIC                                  0.77       0.78  2.17        0.02
# LassoCV                                      0.77       0.78  2.17        0.16
# LassoLarsCV                                  0.77       0.78  2.17        0.04
# LarsCV                                       0.77       0.78  2.17        0.06
# Lars                                         0.77       0.78  2.17        0.03
# TransformedTargetRegressor                   0.77       0.78  2.17        0.02
# LinearRegression                             0.77       0.78  2.17        0.02
# OrthogonalMatchingPursuitCV                  0.77       0.78  2.17        0.03
# RidgeCV                                      0.77       0.78  2.17        0.04
# Ridge                                        0.77       0.78  2.17        0.04
# BayesianRidge                                0.77       0.78  2.17        0.04
# ElasticNetCV                                 0.77       0.78  2.17        0.30
# LinearSVR                                    0.77       0.78  2.18        0.02
# SGDRegressor                                 0.77       0.78  2.18        0.04
# OrthogonalMatchingPursuit                    0.75       0.76  2.27        0.02
# LassoLars                                    0.71       0.72  2.47        0.02
# Lasso                                        0.71       0.72  2.47        0.03
# GaussianProcessRegressor                     0.67       0.69  2.61        0.17
# ElasticNet                                   0.66       0.68  2.65        0.05
# TweedieRegressor                             0.65       0.66  2.71        0.02
# PoissonRegressor                             0.64       0.65  2.75        0.03
# PassiveAggressiveRegressor                   0.15       0.19  4.20        0.03
# DummyRegressor                              -0.05      -0.00  4.67        0.04
# KernelRidge                                 -2.20      -2.06  8.17        0.07

# %%
def evaluate_performa(X_test, y_test, model1, model2, model3, model4, model5, model6):
    rate = [0, 0, 0, 0, 0, 0]
    #difference = [0, 0, 0, 0, 0]

    X_test = X_test.reset_index(drop=True)
    for i, _ in X_test.iterrows():
        X = np.array(X_test.iloc[[i]])
        y = np.array(y_test.iloc[[i]])
        difference = [0, 0, 0, 0, 0, 0]
        difference[0] = abs(model1.predict(X) - y[0])
        difference[1] = abs(model2.predict(X) - y[0])
        difference[2] = abs(model3.predict(X) - y[0])
        difference[3] = abs(model4.predict(X) - y[0])
        difference[4] = abs(model5.predict(X) - y[0])
        difference[5] = abs(model6.predict(X) - y[0])
        print(difference)

        a = int(np.argmin(difference))
        print(a)
        for i in range(len(difference)):
            if difference[a] == difference[i]:
                rate[i] += 1
    
    a = f"Best model : {rate.index(max(rate))+1}"
    return a, rate

# %%
forest = RandomForestRegressor()
gradient = GradientBoostingRegressor()
ada = AdaBoostRegressor()
extra = ExtraTreesRegressor()
knn = KNeighborsRegressor()
bagging = BaggingRegressor()

forest.fit(X_train, y_train)
gradient.fit(X_train, y_train)
ada.fit(X_train, y_train)
extra.fit(X_train, y_train)
knn.fit(X_train, y_train)
bagging.fit(X_train, y_train)

a = evaluate_performa(X_test, y_test
# [array([1.52]), array([1.41538264]), array([0.95154185]), array([1.88]), array([4.4]), array([1.9])]
# 2
# [array([1.03]), array([0.13833184]), array([1.66666667]), array([0.85]), array([1.2]), array([0.7])]
# 1
# [array([1.3]), array([1.46538969]), array([1.38823529]), array([1.5]), array([1.4]), array([1.1])]
# 5
# [array([0.66]), array([0.46349344]), array([0.38823529]), array([0.23]), array([1.4]), array([0.3])]
# 3
# [array([0.88]), array([1.16315639]), array([0.82380952]), array([1.39]), array([0.]), array([0.5])]
# 4
# [array([1.22]), array([1.22423228]), array([1.82380952]), array([0.73]), array([0.6]), array([0.9])]
# 4
# [array([0.02]), array([0.1032895]), array([0.55520505]), array([0.07]), array([1.]), array([0.1])]
# 0
# [array([1.41]), array([1.42217944]), array([1.75698324]), array([1.21]), array([0.4]), array([1.8])]
# 4
# [array([0.27]), array([0.51515136]), array([0.61176471]), array([0.22]), array([2.8]), array([0.2])]
# 5
# [array([1.01]), array([0.54253244]), array([0.24301676]), array([1.4]), array([1.4]), array([0.3])]
# 2
# [array([1.02]), array([1.22977378]), array([1.38823529]), array([0.7]), array([1.8]), array([0.8])]
# 3
# [array([0.35]), array([0.77804345]), array([0.4491018]), array([0.5]), array([2.8]), array([0.3])]
# 5
# [array([0.75]), array([0.02001558]), array([0.44479495]), array([0.46]), array([1.]), array([0.3])]
# 1
# [array([1.88]), array([1.96356526]), array([2.04845815]), array([2.]), array([0.]), array([1.7])]
# 4
# [array([0.01]), array([0.40155627]), array([0.03636364]), array([0.01]), array([1.]), array([0.1])]
# 0
# [array([0.95]), array([1.63806177]), array([1.4491018]), array([0.99]), array([0.]), array([1.1])]
# 4
# [array([0.4]), array([0.50442738]), array([0.44479495]), array([0.55]), array([1.]), array([1.2])]
# 0
# [array([0.46]), array([0.6906266]), array([0.24301676]), array([0.79]), array([2.2]), array([0.3])]
# 2
# [array([1.12]), array([0.92117755]), array([0.75698324]), array([0.78]), array([0.8]), array([1.5])]
# 2
# [array([1.71]), array([1.59546784]), array([1.55520505]), array([1.81]), array([1.8]), array([2.2])]
# 2
# [array([1.82]), array([1.65977141]), array([1.24301676]), array([1.93]), array([3.]), array([1.4])]
# 2
# [array([1.33]), array([1.79264317]), array([1.95154185]), array([1.05]), array([2.6]), array([0.7])]
# 5
# [array([1.31]), array([0.70801082]), array([1.17619048]), array([0.82]), array([1.]), array([1.4])]
# 1
# [array([1.01]), array([1.41958746]), array([1.4491018]), array([1.19]), array([3.]), array([0.6])]
# 5
# [array([1.51]), array([1.20088512]), array([1.61176471]), array([1.6]), array([3.4]), array([1.1])]
# 5
# [array([0.03]), array([0.36726882]), array([0.17619048]), array([0.06]), array([0.2]), array([0.2])]
# 0
# [array([1.02]), array([1.69361225]), array([1.75698324]), array([1.57]), array([1.4]), array([0.9])]
# 5
# [array([1.82]), array([2.0582148]), array([1.82380952]), array([2.07]), array([1.4]), array([1.4])]
# 4
# ('Best model : 5', [14, 29, 43, 24, 54, 42])
