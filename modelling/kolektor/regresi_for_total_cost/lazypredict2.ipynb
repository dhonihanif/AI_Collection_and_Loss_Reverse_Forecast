# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler, LabelEncoder
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor, ExtraTreesRegressor, HistGradientBoostingRegressor, BaggingRegressor
from lazypredict.Supervised import LazyRegressor

# %%
df = pd.read_csv("./data/data2.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                1000 non-null   int64
#  1   avg_bill_methods          1000 non-null   object
#  2   debtor_volume_handled     1000 non-null   int64
#  3   bill_amount_collected     1000 non-null   int64
#  4   total_actual              1000 non-null   int64
#  5   total_cost                1000 non-null   int64
#  6   success_rate              1000 non-null   float64
#  7   time_to_collect           1000 non-null   int64
#  8   collector_gender          1000 non-null   object
#  9   collector_marital_status  1000 non-null   object
#  10  collector_age             1000 non-null   int64
# dtypes: float64(1), int64(7), object(3)
# memory usage: 86.1+ KB

# %%
for i in df.columns:
    if df[i].dtype == "object":
        df[i] = df[i].astype("category")

df.drop(["Unnamed: 0"], axis=1, inplace=True)

# %%
df.head()
# Out:
#   avg_bill_methods  debtor_volume_handled  bill_amount_collected  \
# 0        sms or WA                     10               61600000
# 1        sms or WA                     15               32800000
# 2        sms or WA                     10               38400000
# 3        sms or WA                      9               32500000
# 4        sms or WA                      6               21000000
#
#    total_actual  total_cost  success_rate  time_to_collect collector_gender  \
# 0      67200000       72549         92.00                0        laki-laki
# 1     140200000       86235         23.00                3        perempuan
# 2      55300000       99363         69.00                1        laki-laki
# 3      57400000       76118         57.00                1        perempuan
# 4      25400000       61461         83.00                4        perempuan
#
#   collector_marital_status  collector_age
# 0                  Menikah             45
# 1               Cerai mati             32
# 2              Cerai hidup             62
# 3               Cerai mati             55
# 4                  Menikah             53

# %%
df["avg_bill_methods"].value_counts()
# Out:
# avg_bill_methods
# sms or WA           300
# panggilan           250
# surat panggilan     250
# datang ke tempat    200
# Name: count, dtype: int64

# %%
bill_methods = LabelEncoder().fit(df["avg_bill_methods"].to_numpy().reshape(-1, 1))
gender = LabelEncoder().fit(df["collector_gender"].to_numpy().reshape(-1, 1))
mart = LabelEncoder().fit(df["collector_marital_status"].to_numpy().reshape(-1, 1))
df2 = pd.DataFrame()

df2["avg_bill_methods"] = bill_methods.transform(df["avg_bill_methods"])
df2["collector_gender"] = gender.transform(df["collector_gender"])
df2["collector_marital_status"] = mart.transform(df["collector_marital_status"])
           
scaler = RobustScaler().fit(df[["bill_amount_collected", "total_actual"]])
df2[["bill_amount_collected", "total_actual"]] = scaler.transform(df[["bill_amount_collected", "total_actual"]])
df2[["time_to_collect", "debtor_volume_handled", "collector_age", "success_rate"]] = df[["time_to_collect", "debtor_volume_handled", "collector_age", "success_rate"]]
y = df["total_cost"]

df2.head(5)
# Out:
#    avg_bill_methods  collector_gender  collector_marital_status  \
# 0                 2                 0                         3
# 1                 2                 1                         2
# 2                 2                 0                         1
# 3                 2                 1                         2
# 4                 2                 1                         3
#
#    bill_amount_collected  total_actual  time_to_collect  \
# 0                  -0.19         -0.35                0
# 1                  -0.33         -0.18                3
# 2                  -0.30         -0.37                1
# 3                  -0.33         -0.37                1
# 4                  -0.39         -0.44                4
#
#    debtor_volume_handled  collector_age  success_rate
# 0                     10             45         92.00
# 1                     15             32         23.00
# 2                     10             62         69.00
# 3                      9             55         57.00
# 4                      6             53         83.00

# %%
X = df2

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42)
reg = LazyRegressor(verbose=0, ignore_warnings=True)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)
models
# Out:
#  12%|█▏        | 5/42 [00:00<00:04,  8.55it/s]
#  98%|█████████▊| 41/42 [00:11<00:00,  3.49it/s]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000679 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 747
# [LightGBM] [Info] Number of data points in the train set: 800, number of used features: 9
# [LightGBM] [Info] Start training from score 925718.230000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 100%|██████████| 42/42 [00:12<00:00,  3.41it/s]
#                                Adjusted R-Squared  R-Squared       RMSE  \
# Model
# RandomForestRegressor                        0.95       0.95  201483.06
# BaggingRegressor                             0.95       0.95  201938.42
# GradientBoostingRegressor                    0.95       0.95  204553.93
# ExtraTreesRegressor                          0.95       0.95  205119.45
# AdaBoostRegressor                            0.95       0.95  206283.75
# LGBMRegressor                                0.94       0.95  216599.81
# HistGradientBoostingRegressor                0.94       0.94  222988.11
# XGBRegressor                                 0.94       0.94  223451.02
# OrthogonalMatchingPursuitCV                  0.93       0.93  243019.90
# DecisionTreeRegressor                        0.93       0.93  243027.31
# LassoCV                                      0.93       0.93  244719.06
# LassoLarsCV                                  0.93       0.93  244732.76
# LarsCV                                       0.93       0.93  244732.76
# LassoLarsIC                                  0.93       0.93  244834.57
# RidgeCV                                      0.93       0.93  245338.09
# BayesianRidge                                0.93       0.93  245574.27
# Ridge                                        0.93       0.93  245612.51
# LassoLars                                    0.93       0.93  245650.00
# Lasso                                        0.93       0.93  245650.03
# TransformedTargetRegressor                   0.93       0.93  245650.32
# LinearRegression                             0.93       0.93  245650.32
# Lars                                         0.93       0.93  245650.32
# SGDRegressor                                 0.93       0.93  245817.85
# HuberRegressor                               0.93       0.93  248528.72
# PoissonRegressor                             0.92       0.92  265192.75
# KNeighborsRegressor                          0.91       0.92  267739.38
# ElasticNet                                   0.91       0.91  279647.74
# ExtraTreeRegressor                           0.90       0.91  285929.10
# TweedieRegressor                             0.87       0.88  328515.55
# RANSACRegressor                              0.87       0.87  332343.86
# OrthogonalMatchingPursuit                    0.84       0.84  370633.81
# GammaRegressor                               0.72       0.73  487129.80
# GaussianProcessRegressor                     0.70       0.71  504383.27
# PassiveAggressiveRegressor                   0.66       0.67  534418.08
# ElasticNetCV                                -0.04       0.01  932221.90
# DummyRegressor                              -0.05      -0.00  936126.09
# NuSVR                                       -0.08      -0.03  948752.18
# KernelRidge                                 -0.11      -0.06  962975.40
# SVR                                         -0.24      -0.19 1019350.05
# LinearSVR                                   -1.16      -1.06 1343587.21
# MLPRegressor                                -1.16      -1.06 1343642.93
#
#                                Time Taken
# Model
# RandomForestRegressor                1.54
# BaggingRegressor                     0.22
# GradientBoostingRegressor            0.48
# ExtraTreesRegressor                  0.72
# AdaBoostRegressor                    0.42
# LGBMRegressor                        0.73
# HistGradientBoostingRegressor        2.57
# XGBRegressor                         0.67
# OrthogonalMatchingPursuitCV          0.04
# DecisionTreeRegressor                0.05
# LassoCV                              0.23
# LassoLarsCV                          0.07
# LarsCV                               0.06
# LassoLarsIC                          0.05
# RidgeCV                              0.05
# BayesianRidge                        0.05
# Ridge                                0.04
# LassoLars                            0.04
# Lasso                                0.03
# TransformedTargetRegressor           0.04
# LinearRegression                     0.03
# Lars                                 0.04
# SGDRegressor                         0.09
# HuberRegressor                       0.07
# PoissonRegressor                     0.05
# KNeighborsRegressor                  0.04
# ElasticNet                           0.04
# ExtraTreeRegressor                   0.03
# TweedieRegressor                     0.06
# RANSACRegressor                      0.20
# OrthogonalMatchingPursuit            0.03
# GammaRegressor                       0.04
# GaussianProcessRegressor             0.18
# PassiveAggressiveRegressor           0.19
# ElasticNetCV                         0.23
# DummyRegressor                       0.03
# NuSVR                                0.14
# KernelRidge                          0.11
# SVR                                  0.30
# LinearSVR                            0.03
# MLPRegressor                         2.20

# %%
y.describe()
# Out:
# count      1000.00
# mean     933656.32
# std      910148.06
# min        5624.00
# 25%      118628.50
# 50%      568615.00
# 75%     1502473.25
# max     3582769.00
# Name: total_cost, dtype: float64

# %%
def evaluate_performa(X_test, y_test, model1, model2, model3, model4, model5, model6):
    rate = [0, 0, 0, 0, 0, 0]
    #difference = [0, 0, 0, 0, 0]

    X_test = X_test.reset_index(drop=True)
    for i, _ in X_test.iterrows():
        X = np.array(X_test.iloc[[i]])
        y = np.array(y_test.iloc[[i]])
        difference = [0, 0, 0, 0, 0, 0]
        difference[0] = abs(model1.predict(X) - y[0])
        difference[1] = abs(model2.predict(X) - y[0])
        difference[2] = abs(model3.predict(X) - y[0])
        difference[3] = abs(model4.predict(X) - y[0])
        difference[4] = abs(model5.predict(X) - y[0])
        difference[5] = abs(model6.predict(X) - y[0])
        print(difference)

        a = int(np.argmin(difference))
        print(a)
        for i in range(len(difference)):
            if difference[a] == difference[i]:
                rate[i] += 1
    
    a = f"Best model : {rate.index(max(rate))+1}"
    return a, rate

# %%
forest = RandomForestRegressor()
gradient = GradientBoostingRegressor()
ada = AdaBoostRegressor()
extra = ExtraTreesRegressor()
hist = HistGradientBoostingRegressor()
bagging = BaggingRegressor()

forest.fit(X_train, y_train)
gradient.fit(X_train, y_train)
ada.fit(X_train, y_train)
extra.fit(X_train, y_train)
hist.fit(X_train, y_train)
bagging.fit(X_train, y_train)

a = evaluate_performa(X_test, y_test, forest, gradient, ada, extra, hist, bagging)
a
# Out:
# [array([3705.45]), array([1265.74639933]), array([69778.22377622]), array([11566.27]), array([7233.69384775]), array([15491.5])]
# 1
# [array([101264.59]), array([153750.63074208]), array([154100.99270073]), array([79936.4]), array([111285.4938068]), array([29140.8])]
# 5
# [array([69251.86]), array([9113.48218561]), array([75774.03278689]), array([19996.72]), array([19229.2721338]), array([146836.5])]
# 1
# [array([168065.39]), array([112672.8972059]), array([164623.5112782]), array([148490.42]), array([297043.22679753]), array([116197.1])]
# 1
# [array([63542.07]), array([73004.19021668]), array([13474.68932039]), array([89658.66]), array([106498.88788907]), array([70534.8])]
# 2
# [array([202538.99]), array([87722.05646912]), array([157417.18905473]), array([125670.45]), array([198826.60757628]), array([38201.2])]
# 5
# [array([215893.86]), array([149798.70812022]), array([163161.76470588]), array([279586.63]), array([200290.69572162]), array([324457.1])]
# 1
# [array([117322.03]), array([84930.84704718]), array([125313.54545455]), array([134899.43]), array([101118.06611672]), array([85421.5])]
# 1
# [array([449421.38]), array([553664.39674535]), array([490350.16393443]), array([406971.51]), array([524196.92900553]), array([589003.4])]
# 3
# [array([8737.65]), array([17378.23585469]), array([84908.71764706]), array([12125.2]), array([17240.08485256]), array([21423.6])]
# 0
# [array([496565.37]), array([429533.24982453]), array([353581.34653465]), array([478987.2]), array([460003.27542426]), array([506036.1])]
# 2
# [array([28477.96]), array([11241.77752817]), array([83677.71764706]), array([26997.75]), array([17951.49854409]), array([32213.2])]
# 1
# [array([188111.33]), array([21923.33944621]), array([66461.76470588]), array([190462.04]), array([173970.09724706]), array([243003.1])]
# 1
# [array([53894.93]), array([705.63871242]), array([18125.37391304]), array([160144.9]), array([15830.42982218]), array([5540.8])]
# 1
# 0
# [array([13284.84]), array([12201.19247344]), array([67895.71764706]), array([3610.36]), array([4236.20526918]), array([16380.8])]
# 3
# [array([46960.42]), array([47256.19303751]), array([146125.63235294]), array([42403.57]), array([61364.61692446]), array([32279.8])]
# 5
# [array([125826.84]), array([10403.83897059]), array([104742.04347826]), array([96113.34]), array([122167.25013811]), array([124710.4])]
# 1
# [array([114678.85]), array([50218.89952354]), array([132565.91891892]), array([109779.56]), array([7724.145142]), array([51480.9])]
# 4
# [array([114253.57]), array([117839.55375399]), array([37140.5304878]), array([197542.92]), array([208573.6705821]), array([109554.3])]
# 2
# [array([196141.04]), array([320479.07038071]), array([252602.74545455]), array([239812.08]), array([218862.51438068]), array([230420.7])]
# 0
# [array([263209.31]), array([325190.61773314]), array([219985.53773585]), array([228681.55]), array([199018.45142727]), array([261619.1])]
# 4
# [array([34905.96]), array([70869.34121745]), array([1825.4695122]), array([15651.32]), array([110351.92350355]), array([45239.3])]
# 2
# [array([2231.96]), array([7702.19305101]), array([121802.71764706]), array([7619.71]), array([4759.15745893]), array([241.8])]
# 5
# [array([9499.04]), array([22863.66326919]), array([108496.71764706]), array([16457.08]), array([25779.04323815]), array([9759.2])]
# 0
# [array([137667.49]), array([126327.87971254]), array([113877.45652174]), array([51380.38]), array([184090.89342228]), array([150748.8])]
# 3
# [array([41628.41]), array([59069.94233833]), array([44303.45652174]), array([62542.75]), array([138745.53325703]), array([24601.3])]
# 5
# [array([35389.69]), array([43698.17012525]), array([74939.71764706]), array([32107.05]), array([29436.76304477]), array([45666.9])]
# 4
# [array([169976.21]), array([102978.54014134]), array([70527.76470588]), array([162173.09]), array([232708.46513508]), array([289581.9])]
# 2
# [array([6053.66]), array([28452.42941704]), array([99789.71764706]), array([6632.7]), array([17764.86287245]), array([2236.8])]
# 5
# ('Best model : 6', [23, 47, 27, 27, 26, 50])

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_absolute_percentage_error, mean_squared_error
name = ["ExtraTreeRegressor", "GradientBoosting", "Ada", "RandomForest", "BaggingRegressor"]
estimators = [extra, forest, ada, gradient, bagging]
r_square = [r2_score(y_test, i.predict(X_test)) for i in estimators]
mse = [mean_squared_error(y_test, i.predict(X_test)) for i in estimators]
mae = [mean_absolute_error(y_test, i.predict(X_test)) for i in estimators]
rmse = [i ** (1/2) for i in mse]
mape = [mean_absolute_percentage_error(y_test, i.predict(X_test)) for i in estimators]


estimate = pd.DataFrame({
    "name": name,
    "r_square": r_square,
    "mse": mse,
    "mae": mae,
    "rmse": rmse,
    "mape": mape
}
)
estimate
# Out:
#                  name  r_square            mse       mae      rmse  mape
# 0  ExtraTreeRegressor      0.95 42274956746.48 137851.39 205608.75  0.21
# 1    GradientBoosting      0.95 40384097688.11 131904.59 200957.95  0.20
# 2                 Ada      0.95 43028911199.12 164458.50 207434.11  1.05
# 3        RandomForest      0.95 42190419107.78 134815.55 205403.06  0.23
# 4    BaggingRegressor      0.95 45331055128.37 134950.77 212910.91  0.20
