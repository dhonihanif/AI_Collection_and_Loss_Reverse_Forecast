# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler, LabelEncoder
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor, ExtraTreesRegressor, HistGradientBoostingRegressor, BaggingRegressor
from lazypredict.Supervised import LazyRegressor

# %%
df = pd.read_csv("./data/data2.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                1000 non-null   int64
#  1   avg_bill_methods          1000 non-null   object
#  2   debtor_volume_handled     1000 non-null   int64
#  3   bill_amount_collected     1000 non-null   int64
#  4   total_actual              1000 non-null   int64
#  5   total_cost                1000 non-null   int64
#  6   success_rate              1000 non-null   float64
#  7   time_to_collect           1000 non-null   int64
#  8   collector_gender          1000 non-null   object
#  9   collector_marital_status  1000 non-null   object
#  10  collector_age             1000 non-null   int64
# dtypes: float64(1), int64(7), object(3)
# memory usage: 86.1+ KB

# %%
for i in df.columns:
    if df[i].dtype == "object":
        df[i] = df[i].astype("category")

df.drop(["Unnamed: 0"], axis=1, inplace=True)

# %%
df.head()
# Out:
#   avg_bill_methods  debtor_volume_handled  bill_amount_collected  \
# 0        sms or WA                     10               61600000
# 1        sms or WA                     15               32800000
# 2        sms or WA                     10               38400000
# 3        sms or WA                      9               32500000
# 4        sms or WA                      6               21000000
#
#    total_actual  total_cost  success_rate  time_to_collect collector_gender  \
# 0      67200000       72549         92.00                0        laki-laki
# 1     140200000       86235         23.00                3        perempuan
# 2      55300000       99363         69.00                1        laki-laki
# 3      57400000       76118         57.00                1        perempuan
# 4      25400000       61461         83.00                4        perempuan
#
#   collector_marital_status  collector_age
# 0                  Menikah             45
# 1               Cerai mati             32
# 2              Cerai hidup             62
# 3               Cerai mati             55
# 4                  Menikah             53

# %%
df["avg_bill_methods"].value_counts()
# Out:
# avg_bill_methods
# sms or WA           300
# panggilan           250
# surat panggilan     250
# datang ke tempat    200
# Name: count, dtype: int64

# %%
bill_methods = LabelEncoder().fit(df["avg_bill_methods"].to_numpy().reshape(-1, 1))
gender = LabelEncoder().fit(df["collector_gender"].to_numpy().reshape(-1, 1))
mart = LabelEncoder().fit(df["collector_marital_status"].to_numpy().reshape(-1, 1))
df2 = pd.DataFrame()

df2["avg_bill_methods"] = bill_methods.transform(df["avg_bill_methods"])
df2["collector_gender"] = gender.transform(df["collector_gender"])
df2["collector_marital_status"] = mart.transform(df["collector_marital_status"])
           
scaler = RobustScaler().fit(df[["bill_amount_collected", "total_actual"]])
df2[["bill_amount_collected", "total_actual"]] = scaler.transform(df[["bill_amount_collected", "total_actual"]])
df2[["time_to_collect", "debtor_volume_handled", "collector_age", "success_rate"]] = df[["time_to_collect", "debtor_volume_handled", "collector_age", "success_rate"]]
y = df["total_cost"]

df2.head(5)
# Out:
#    avg_bill_methods  collector_gender  collector_marital_status  \
# 0                 2                 0                         3
# 1                 2                 1                         2
# 2                 2                 0                         1
# 3                 2                 1                         2
# 4                 2                 1                         3
#
#    bill_amount_collected  total_actual  time_to_collect  \
# 0                  -0.19         -0.35                0
# 1                  -0.33         -0.18                3
# 2                  -0.30         -0.37                1
# 3                  -0.33         -0.37                1
# 4                  -0.39         -0.44                4
#
#    debtor_volume_handled  collector_age  success_rate
# 0                     10             45         92.00
# 1                     15             32         23.00
# 2                     10             62         69.00
# 3                      9             55         57.00
# 4                      6             53         83.00

# %%
X = df2

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42)
reg = LazyRegressor(verbose=0, ignore_warnings=True)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)
models
# Out:
#  14%|█▍        | 6/42 [00:00<00:02, 13.22it/s]
# 100%|██████████| 42/42 [00:07<00:00,  5.72it/s]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000215 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 747
# [LightGBM] [Info] Number of data points in the train set: 800, number of used features: 9
# [LightGBM] [Info] Start training from score 925718.230000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#                                Adjusted R-Squared  R-Squared       RMSE  \
# Model
# RandomForestRegressor                        0.95       0.95  201483.06
# BaggingRegressor                             0.95       0.95  201938.42
# GradientBoostingRegressor                    0.95       0.95  204553.93
# ExtraTreesRegressor                          0.95       0.95  205119.45
# AdaBoostRegressor                            0.95       0.95  206283.75
# LGBMRegressor                                0.94       0.95  216599.81
# HistGradientBoostingRegressor                0.94       0.94  222988.11
# XGBRegressor                                 0.94       0.94  223451.02
# OrthogonalMatchingPursuitCV                  0.93       0.93  243019.90
# DecisionTreeRegressor                        0.93       0.93  243027.31
# LassoCV                                      0.93       0.93  244719.06
# LassoLarsCV                                  0.93       0.93  244732.76
# LarsCV                                       0.93       0.93  244732.76
# LassoLarsIC                                  0.93       0.93  244834.57
# RidgeCV                                      0.93       0.93  245338.09
# BayesianRidge                                0.93       0.93  245574.27
# Ridge                                        0.93       0.93  245612.51
# LassoLars                                    0.93       0.93  245650.00
# Lasso                                        0.93       0.93  245650.03
# TransformedTargetRegressor                   0.93       0.93  245650.32
# LinearRegression                             0.93       0.93  245650.32
# Lars                                         0.93       0.93  245650.32
# SGDRegressor                                 0.93       0.93  245817.85
# HuberRegressor                               0.93       0.93  248528.72
# PoissonRegressor                             0.92       0.92  265192.75
# KNeighborsRegressor                          0.91       0.92  267739.38
# ElasticNet                                   0.91       0.91  279647.74
# ExtraTreeRegressor                           0.90       0.91  285929.10
# TweedieRegressor                             0.87       0.88  328515.55
# RANSACRegressor                              0.87       0.87  332343.86
# OrthogonalMatchingPursuit                    0.84       0.84  370633.81
# GammaRegressor                               0.72       0.73  487129.80
# GaussianProcessRegressor                     0.70       0.71  504383.27
# PassiveAggressiveRegressor                   0.66       0.67  534418.08
# ElasticNetCV                                -0.04       0.01  932221.90
# DummyRegressor                              -0.05      -0.00  936126.09
# NuSVR                                       -0.08      -0.03  948752.18
# KernelRidge                                 -0.11      -0.06  962975.40
# SVR                                         -0.24      -0.19 1019350.05
# LinearSVR                                   -1.16      -1.06 1343587.21
# MLPRegressor                                -1.16      -1.06 1343642.93
#
#                                Time Taken
# Model
# RandomForestRegressor                1.46
# BaggingRegressor                     0.20
# GradientBoostingRegressor            0.44
# ExtraTreesRegressor                  1.14
# AdaBoostRegressor                    0.31
# LGBMRegressor                        0.15
# HistGradientBoostingRegressor        0.62
# XGBRegressor                         0.28
# OrthogonalMatchingPursuitCV          0.04
# DecisionTreeRegressor                0.04
# LassoCV                              0.14
# LassoLarsCV                          0.03
# LarsCV                               0.04
# LassoLarsIC                          0.02
# RidgeCV                              0.02
# BayesianRidge                        0.02
# Ridge                                0.02
# LassoLars                            0.02
# Lasso                                0.02
# TransformedTargetRegressor           0.02
# LinearRegression                     0.02
# Lars                                 0.02
# SGDRegressor                         0.02
# HuberRegressor                       0.04
# PoissonRegressor                     0.03
# KNeighborsRegressor                  0.02
# ElasticNet                           0.02
# ExtraTreeRegressor                   0.08
# TweedieRegressor                     0.03
# RANSACRegressor                      0.08
# OrthogonalMatchingPursuit            0.02
# GammaRegressor                       0.20
# GaussianProcessRegressor             0.15
# PassiveAggressiveRegressor           0.10
# ElasticNetCV                         0.20
# DummyRegressor                       0.02
# NuSVR                                0.07
# KernelRidge                          0.05
# SVR                                  0.11
# LinearSVR                            0.02
# MLPRegressor                         1.02

# %%
y.describe()
# Out:
# count      1000.00
# mean     933656.32
# std      910148.06
# min        5624.00
# 25%      118628.50
# 50%      568615.00
# 75%     1502473.25
# max     3582769.00
# Name: total_cost, dtype: float64

# %%
def evaluate_performa(X_test, y_test, model1, model2, model3, model4, model5, model6):
    rate = [0, 0, 0, 0, 0, 0]
    #difference = [0, 0, 0, 0, 0]

    X_test = X_test.reset_index(drop=True)
    for i, _ in X_test.iterrows():
        X = np.array(X_test.iloc[[i]])
        y = np.array(y_test.iloc[[i]])
        difference = [0, 0, 0, 0, 0, 0]
        difference[0] = abs(model1.predict(X) - y[0])
        difference[1] = abs(model2.predict(X) - y[0])
        difference[2] = abs(model3.predict(X) - y[0])
        difference[3] = abs(model4.predict(X) - y[0])
        difference[4] = abs(model5.predict(X) - y[0])
        difference[5] = abs(model6.predict(X) - y[0])
        print(difference)

        a = int(np.argmin(difference))
        print(a)
        for i in range(len(difference)):
            if difference[a] == difference[i]:
                rate[i] += 1
    
    a = f"Best model : {rate.index(max(rate))+1}"
    return a, rate

# %%
forest = RandomForestRegressor()
gradient = GradientBoostingRegressor()
ada = AdaBoostRegressor()
extra = ExtraTreesRegressor()
hist = HistGradientBoostingRegressor()
bagging = BaggingRegressor()

forest.fit(X_train, y_train)
gradient.fit(X_train, y_train)
ada.fit(X_train, y_train)
extra.fit(X_train, y_train)
hist.fit(X_train, y_train)
bagging.fit(X_train, y_train)

a = evaluate_performa(X_test, y_test, forest, gradient, ada, extra, hist, bagging)
a
# Out:
# [array([3298.82]), array([1265.74639933]), array([84215.70731707]), array([12295.61]), array([7233.69384775]), array([21301.8])]
# 1
# [array([152084.97]), array([153750.63074208]), array([145234.18235294]), array([119058.48]), array([111285.4938068]), array([110013.])]
# 5
# [array([90501.17]), array([9113.48218561]), array([40263.74162679]), array([3177.13]), array([19229.2721338]), array([31777.7])]
# 3
# [array([197044.97]), array([112672.8972059]), array([178743.13664596]), array([97080.47]), array([297043.22679753]), array([181717.2])]
# 3
# [array([51453.87]), array([73004.19021668]), array([8088.29268293]), array([79440.61]), array([106498.88788907]), array([56093.8])]
# 2
# [array([195462.29]), array([87722.05646912]), array([132063.76632302]), array([125799.96]), array([198826.60757628]), array([231878.3])]
# 1
# [array([221313.85]), array([149798.70812022]), array([185061.34782609]), array([266668.59]), array([200290.69572162]), array([93057.2])]
# 5
# [array([134522.15]), array([84930.84704718]), array([123757.8]), array([135212.84]), array([101118.06611672]), array([141735.4])]
# 1
# [array([487091.43]), array([553664.39674535]), array([479289.06578947]), array([436855.35]), array([524196.92900553]), array([533554.4])]
# 3
# [array([11882.32]), array([17378.23585469]), array([92187.]), array([13890.36]), array([17240.08485256]), array([14632.8])]
# 0
# [array([521158.58]), array([429533.24982453]), array([368195.43434343]), array([575247.26]), array([460003.27542426]), array([433051.4])]
# 2
# [array([22176.12]), array([11241.77752817]), array([90956.]), array([25944.25]), array([17951.49854409]), array([20741.7])]
# 1
# [array([232008.57]), array([21923.33944621]), array([80703.90178571]), array([149163.31]), array([173970.09724706]), array([189467.4])]
# 1
# [array([56708.24]), array([705.63871242]), array([26659.40145985]), array([160412.12]), array([15830.42982218]), array([22762.1])]
# 1
# [array([393729.93]), array([549418.5417642]), array([443411.1040724]), array([407479.68]), array([554549.92105928]), array([383053.6])]
# 5
# [array([167822.37]), array([219530.36432752]), array([258039.16806723]), array([331370.27]), array([314765.44386528]), array([298783.1])]
# 0
# [array([62714.04]), array([53463.84441397]), array([93552.5]), array([70528.32]), array([63527.63477946]), array([56762.1])]
# 1
# [array([330769.37]), array([295419.4616658]), array([243501.75324675]), array([289076.08]), array([437963.58778371]), array([121307.])]
# 5
# [array([124317.07]), array([104142.78419703]), array([134583.20987654]), array([193401.99]), array([7351.04093802]), array([154886.])]
# 4
# [array([209716.56]), array([188501.38333294]), array([91905.16030534]), array([197874.84]), array([238294.49403469]), array([182091.])]
# 2
# [array([137968.48]), array([80116.507502]), array([102634.44827586]), array([183176.57]), array([89333.19586491]), array([178537.8])]
# 1
# [array([13265.21]), array([416.73898269]), array([106577.]), array([12185.31]), array([18265.54041184]), array([3980.5])]
# 1
# [array([96764.73]), array([77138.83293611]), array([79680.16030534]), array([108662.77]), array([177195.36656357]), array([131555.3])]
# 1
# [array([75374.45]), array([107680.21473778]), array([77494.87401575]), array([113271.14]), array([95329.11491974]), array([51005.3])]
# 5
# [array([7872.01]), array([13796.20496471]), array([177918.]), array([8595.88]), array([9972.36298649]), array([6937.7])]
# 5
# [array([16930.93]), array([2424.79293698]), array([138759.]), array([17708.49]), array([17935.12781381]), array([16121.6])]
# 1
# [array([15837.06]), array([18063.0899718]), array([122173.]), array([19583.82]), array([14665.88985599]), array([17353.])]
# 4
# [array([24768.01]), array([100946.01805617]), array([34632.484375]), array([46843.24]), array([31769.99373206]), array([97787.9])]
# 0
# [array([341258.29]), array([489671.06832606]), array([395116.4]), array([327765.98]), array([403803.01787414]), array([427262.6])]
# 3
# [array([27336.1]), array([85226.75066811]), array([72482.28125]), array([36144.94]), array([4106.07984243]), array([57052.3])]
# 4
# [array([124074.31]), array([142241.57861412]), array([130824.12598425]), array([150099.7]), array([181916.40644147]), array([162444.4])]
# 0
# [array([38504.32]), array([18603.31220469]), array([67798.]), array([48379.73]), array([30843.8708349]), array([42654.8])]
# 1
# [array([51564.19]), array([83756.8101787]), array([120377.65217391]), array([68819.8]), array([101064.7538873]), array([47763.3])]
# 5
# [array([57780.16]), array([57526.66108843]), array([60010.29268293]), array([47702.95]), array([87086.47554122]), array([45692.8])]
# 5
# [array([104839.01]), array([92903.71333462]), array([155433.70731707]), array([88469.58]), array([93490.83849326]), array([116680.9])]
# 3
# [array([2844.09]), array([17223.98946848]), array([172006.]), array([3962.04]), array([8953.95285125]), array([2976.6])]
# 0
# [array([360104.74]), array([218542.8188013]), array([291855.90178571]), array([371794.82]), array([334132.2320185]), array([308241.])]
# 1
# [array([529072.72]), array([600187.25403413]), array([504568.04285714]), array([673008.11]), array([741495.45359789]), array([633683.])]
# 2
# [array([300845.43]), array([217038.98547373]), array([323136.33333333]), array([390922.56]), array([240061.33782773]), array([382826.6])]
# 1
# [array([12766.23]), array([20898.41407752]), array([62885.5]), array([20611.89]), array([28239.92517635]), array([8603.2])]
# 5
# [array([7425.77]), array([8510.11762529]), array([53182.83969466]), array([33080.35]), array([33091.87488362]), array([85649.5])]
# 0
# [array([10334.25]), array([8506.75005326]), array([106098.]), array([9446.09]), array([3781.80360323]), array([9614.2])]
# 4
# [array([7787.83]), array([74278.27356386]), array([16426.8]), array([3255.19]), array([106645.42949527]), array([295.1])]
# 5
# [array([88272.33]), array([134508.07541208]), array([148467.11811024]), array([172292.22]), array([181645.59973191]), array([186995.3])]
# 0
# [array([15623.14]), array([31802.40402291]), array([12985.5]), array([7666.61]), array([24912.88413378]), array([34128.8])]
# 3
# [array([41283.01]), array([36487.47930433]), array([99664.]), array([42178.28]), array([39470.95521856]), array([31196.7])]
# 5
# [array([172593.16]), array([125305.74858474]), array([66848.88188976]), array([120067.25]), array([136582.71964137]), array([123886.3])]
# 2
# [array([339855.79]), array([355456.10561743]), array([306693.18235294]), array([304217.63]), array([393567.13687923]), array([357818.6])]
# 3
# [array([41263.21]), array([56188.69581601]), array([3000.70731707]), array([28433.8]), array([14515.2910796]), array([26656.9])]
# 2
# [array([261793.33]), array([125315.6223486]), array([225938.2605042]), array([309247.15]), array([276451.2334342]), array([365198.5])]
# 1
# [array([446974.58]), array([479925.03387452]), array([464330.89958159]), array([298452.91]), array([471701.93074211]), array([260739.9])]
# 5
# [array([643535.]), array([524367.82092285]), array([452560.75]), array([611789.51]), array([594156.45198412]), array([544651.6])]
# 2
# [array([50727.]), array([2923.11394819]), array([14776.5]), array([59440.31]), array([43977.57207379]), array([46730.3])]
# 1
# [array([10236.09]), array([89573.17789282]), array([16408.90763052]), array([31358.06]), array([47513.48294125]), array([101919.9])]
# 0
# [array([63217.44]), array([50488.70770338]), array([14630.5]), array([72685.62]), array([84214.16819502]), array([57839.])]
# 2
# [array([4604.16]), array([2707.31510552]), array([69783.]), array([2887.49]), array([7075.31439188]), array([11505.7])]
# 1
# [array([165225.11]), array([23198.07118283]), array([48970.86138614]), array([227609.17]), array([25191.99316324]), array([282351.2])]
# 1
# [array([644.59]), array([144.24600395]), array([73467.]), array([2562.32]), array([29039.19477503]), array([1625.3])]
# 1
# [array([3723.17]), array([658.12551301]), array([85340.]), array([4164.28]), array([9570.79216826]), array([5084.5])]
# 1
# [array([154646.65]), array([182020.94542202]), array([155879.08474576]), array([264539.2]), array([354265.58647323]), array([369070.4])]
# 0
# [array([18500.75]), array([21720.45641735]), array([130374.]), array([17220.54]), array([16223.01194516]), array([19606.8])]
# 4
# [array([28774.74]), array([22994.46148057]), array([79107.]), array([28675.54]), array([33138.80311416]), array([20644.6])]
# 5
# [array([70336.72]), array([100239.85388078]), array([125216.12598425]), array([56948.44]), array([56066.71771134]), array([37664.4])]
# 5
# [array([340.77]), array([422.47626148]), array([95276.5]), array([10003.1]), array([7100.95739182]), array([5116.9])]
# 0
# [array([69688.81]), array([124973.85909682]), array([168372.13861386]), array([166822.61]), array([180770.48537262]), array([88298.5])]
# 0
# [array([325181.88]), array([441357.86541928]), array([303908.98684211]), array([303617.44]), array([458761.87123701]), array([392767.5])]
# 3
# [array([95296.57]), array([78868.28600691]), array([73454.34782609]), array([154400.5]), array([72740.2935954]), array([200570.2])]
# 4
# [array([228937.3]), array([274871.53191161]), array([311122.60273973]), array([202121.72]), array([237786.74460865]), array([135411.4])]
# 5
# [array([29561.39]), array([15807.87493015]), array([95261.]), array([30961.23]), array([26984.82039319]), array([30727.6])]
# 1
# [array([58349.95]), array([44528.57210072]), array([32366.29268293]), array([85329.41]), array([32952.00153797]), array([83739.6])]
# 2
# [array([2602.08]), array([7808.99915606]), array([142861.]), array([25.2]), array([4596.62012919]), array([438.1])]
# 3
# [array([3570.76]), array([16689.38514468]), array([5027.12598425]), array([42010.08]), array([17534.47595004]), array([36787.2])]
# 0
# [array([251196.69]), array([406150.98853211]), array([272609.98156682]), array([106027.4]), array([368490.90367495]), array([108922.9])]
# 3
# [array([213118.4]), array([348452.8739561]), array([313607.96666667]), array([314135.16]), array([349485.49779599]), array([153245.8])]
# 5
# [array([18094.39]), array([27947.33449777]), array([166520.]), array([19398.31]), array([16920.79763396]), array([19252.8])]
# 4
# [array([32231.75]), array([30842.83308932]), array([64100.]), array([30237.15]), array([32236.20568851]), array([31893.2])]
# 3
# [array([163800.]), array([204812.4894703]), array([141225.63934426]), array([119530.37]), array([253758.98811028]), array([236259.8])]
# 3
# [array([5699.58]), array([1172.53155842]), array([121790.]), array([14398.5]), array([17131.49239902]), array([3778.3])]
# 1
# [array([100315.95]), array([162089.5986177]), array([125509.01986755]), array([146521.88]), array([224252.64853134]), array([67026.5])]
# 5
# [array([1830.68]), array([32513.37230819]), array([58192.70731707]), array([14447.17]), array([46443.68261767]), array([7272.])]
# 0
# [array([274876.89]), array([143192.62091575]), array([262790.87903226]), array([267492.77]), array([193468.41745757]), array([343829.1])]
# 1
# [array([39982.89]), array([28274.78711398]), array([124603.]), array([42826.94]), array([42095.88372922]), array([42125.9])]
# 1
# [array([7783.33]), array([15605.32412469]), array([168802.]), array([7618.96]), array([12982.76234622]), array([11554.3])]
# 3
# [array([1628.25]), array([5754.23320035]), array([44683.]), array([149.02]), array([29111.26717992]), array([19109.4])]
# 3
# [array([45970.84]), array([129551.25882117]), array([134625.66666667]), array([54710.92]), array([54916.72652559]), array([55342.6])]
# 0
# [array([146052.25]), array([101552.29107342]), array([151605.70731707]), array([99067.03]), array([130737.41685463]), array([90829.4])]
# 5
# [array([358446.02]), array([279502.47257785]), array([208695.49484536]), array([335559.91]), array([370527.98291999]), array([392316.6])]
# 2
# [array([185978.83]), array([298859.43598608]), array([311981.55263158]), array([163201.81]), array([206114.78629771]), array([206344.1])]
# 3
# [array([455035.29]), array([255235.21819688]), array([385220.87903226]), array([370880.87]), array([307279.59782015]), array([432721.9])]
# 1
# [array([94128.61]), array([91753.21692452]), array([206728.54421769]), array([115517.74]), array([119517.12854624]), array([88313.2])]
# 5
# [array([52346.18]), array([62619.87645048]), array([16312.83333333]), array([39341.69]), array([74410.11036009]), array([74357.6])]
# 2
# [array([102109.88]), array([118314.68839638]), array([192356.54421769]), array([92351.46]), array([36672.6477755]), array([126287.1])]
# 4
# [array([184882.42]), array([145644.02353087]), array([282288.34285714]), array([105032.29]), array([170937.6834532]), array([223806.9])]
# 3
# [array([11237.87]), array([1453.46809566]), array([113875.]), array([12300.36]), array([10741.00263965]), array([10971.7])]
# 1
# [array([335700.09]), array([394433.06432307]), array([352005.18235294]), array([353546.76]), array([451340.08201034]), array([368427.1])]
# 0
# [array([17686.17]), array([53048.7563868]), array([145453.69565217]), array([28098.82]), array([35722.78997374]), array([20114.3])]
# 0
# [array([692042.36]), array([543481.0205082]), array([522101.67156863]), array([707413.06]), array([804446.79217111]), array([742531.5])]
# 2
# [array([14355.86]), array([9084.16303323]), array([127552.5]), array([12654.73]), array([11267.03060601]), array([11333.5])]
# 1
# [array([2300.82]), array([14357.34178216]), array([171381.]), array([1080.96]), array([2947.07478937]), array([1515.1])]
# 3
# [array([201013.37]), array([265067.46382126]), array([183032.15328467]), array([251457.81]), array([182426.06136191]), array([199670.8])]
# 4
# [array([90044.09]), array([100663.85704395]), array([24722.65217391]), array([45342.82]), array([68646.76136661]), array([82937.6])]
# 2
# [array([53124.23]), array([99743.48709459]), array([119968.70731707]), array([69926.03]), array([96516.79737181]), array([65245.5])]
# 0
# [array([359453.86]), array([443295.25102327]), array([297809.3989071]), array([161532.73]), array([439406.01439052]), array([462827.6])]
# 3
# [array([29332.79]), array([11586.61439139]), array([89938.5]), array([29341.11]), array([28615.70025693]), array([30816.4])]
# 1
# [array([14278.22]), array([65587.4498142]), array([102672.65217391]), array([75960.05]), array([22115.13500267]), array([43090.5])]
# 0
# [array([218545.61]), array([343914.97752639]), array([358704.86335404]), array([250504.12]), array([236939.12316767]), array([187429.7])]
# 5
# [array([138156.2]), array([91726.41270702]), array([166428.65217391]), array([143651.54]), array([145872.78600761]), array([234045.7])]
# 1
# [array([239200.34]), array([376450.58432712]), array([402988.76732673]), array([323541.34]), array([148330.15479419]), array([313940.7])]
# 4
# [array([13566.34]), array([47329.03276345]), array([135719.5]), array([15124.35]), array([30155.01569176]), array([12657.4])]
# 5
# [array([16466.29]), array([47022.31264724]), array([116787.6010929]), array([16435.86]), array([20855.35982647]), array([49888.6])]
# 3
# [array([77615.64]), array([56627.91859545]), array([51823.2]), array([93154.72]), array([43600.86055064]), array([90140.7])]
# 4
# [array([66505.09]), array([7424.82496437]), array([63414.27631579]), array([128669.77]), array([28007.86268947]), array([37001.3])]
# 1
# [array([124997.]), array([93517.92550834]), array([280400.54140127]), array([79664.02]), array([90735.73985593]), array([20429.1])]
# 5
# [array([2166.02]), array([53164.76232244]), array([148687.79032258]), array([109486.75]), array([52861.58631468]), array([58712.6])]
# 0
# [array([445.79]), array([2019.49628344]), array([114865.]), array([5634.75]), array([21542.39215261]), array([4606.8])]
# 0
# [array([55763.18]), array([30989.49979991]), array([149578.69565217]), array([76032.17]), array([100249.30889205]), array([79647.])]
# 1
# [array([5323.09]), array([12161.49057275]), array([150608.]), array([7402.55]), array([358.82656753]), array([3902.8])]
# 4
# [array([45227.42]), array([98478.04300264]), array([8523.81212121]), array([80096.85]), array([75903.21690503]), array([23406.])]
# 2
# [array([83102.14]), array([36166.97977418]), array([142525.34285714]), array([102586.51]), array([81702.13356698]), array([109184.5])]
# 1
# [array([7278.95]), array([9923.87029983]), array([135647.]), array([15580.69]), array([4840.27339326]), array([9927.5])]
# 4
# [array([401740.69]), array([432266.05780814]), array([410554.93243243]), array([350402.55]), array([465892.59781192]), array([420120.])]
# 3
# [array([112110.]), array([75704.131955]), array([180956.83969466]), array([74995.95]), array([80293.00662133]), array([142096.2])]
# 3
# [array([270692.26]), array([149752.51135669]), array([248554.68115942]), array([331360.04]), array([263913.76231697]), array([310575.8])]
# 1
# [array([7712.74]), array([14244.12551301]), array([98926.]), array([22242.3]), array([4983.63193203]), array([7729.8])]
# 4
# [array([14873.04]), array([28736.26101731]), array([135730.]), array([11897.28]), array([20986.97535313]), array([12964.2])]
# 3
# [array([395088.74]), array([248654.37079231]), array([336513.65217391]), array([250489.13]), array([126098.67795514]), array([334001.4])]
# 4
# [array([35800.8]), array([89180.90192277]), array([89128.23140496]), array([27548.3]), array([168386.98244364]), array([151083.8])]
# 3
# [array([132525.54]), array([228108.5506595]), array([192863.83969466]), array([148889.43]), array([106421.7503813]), array([99932.7])]
# 5
# [array([549306.12]), array([674429.14603465]), array([551778.55844156]), array([581316.83]), array([609732.15265698]), array([504752.7])]
# 5
# [array([702173.88]), array([629750.8138989]), array([542614.66968326]), array([675679.15]), array([862208.82574072]), array([816099.7])]
# 2
# [array([524947.8]), array([468379.95660563]), array([423418.7231405]), array([594499.68]), array([556942.73421737]), array([533404.])]
# 2
# [array([551548.89]), array([379152.07230702]), array([424146.39726027]), array([522748.23]), array([323311.150842]), array([636276.5])]
# 4
# [array([3046.23]), array([16991.3187242]), array([162974.]), array([4822.67]), array([9440.55010527]), array([5712.5])]
# 0
# [array([459109.32]), array([551619.3504293]), array([444922.93243243]), array([574263.13]), array([493398.20426277]), array([301639.7])]
# 5
# [array([78767.57]), array([48787.3342686]), array([154015.70731707]), array([74833.25]), array([72594.45318588]), array([79300.6])]
# 1
# [array([1791.18]), array([13881.88518442]), array([170143.]), array([3952.04]), array([8977.55670322]), array([537.])]
# 5
# [array([3398.14]), array([3137.91525067]), array([157013.]), array([5457.2]), array([3489.10053773]), array([6438.2])]
# 1
# [array([2849.3]), array([13560.82020197]), array([175329.]), array([4742.6]), array([513.13796446]), array([3562.9])]
# 4
# [array([20250.6]), array([20586.52250561]), array([143817.]), array([11908.12]), array([9174.42808709]), array([13553.7])]
# 4
# [array([3142.34]), array([2058.78711398]), array([102329.5]), array([5731.67]), array([16846.714901]), array([14733.4])]
# 1
# [array([7447.66]), array([4229.66902464]), array([116370.]), array([5441.51]), array([1370.45379091]), array([8469.9])]
# 4
# [array([31293.17]), array([25862.72552714]), array([133906.5]), array([27327.37]), array([30341.06025839]), array([23795.])]
# 5
# [array([276381.06]), array([344776.0505098]), array([371583.68115942]), array([246065.54]), array([361822.09461264]), array([258551.3])]
# 3
# [array([24162.85]), array([34149.12668584]), array([119718.]), array([24083.03]), array([26902.88171042]), array([25810.])]
# 3
# [array([490847.59]), array([430394.95316704]), array([449603.14912281]), array([510101.76]), array([545236.4969034]), array([524844.8])]
# 1
# [array([333599.94]), array([492183.36304938]), array([399284.75675676]), array([293882.78]), array([434091.92890407]), array([269792.3])]
# 5
# [array([77299.94]), array([207523.01106167]), array([219709.57971015]), array([100514.23]), array([125888.27963015]), array([158171.6])]
# 0
# [array([50909.24]), array([36131.1361797]), array([90940.5]), array([45752.4]), array([30034.86603276]), array([38958.9])]
# 4
# [array([72382.11]), array([93953.80226723]), array([94225.20967742]), array([34396.06]), array([168922.45406579]), array([158284.2])]
# 3
# [array([94031.91]), array([46694.02838204]), array([184935.66666667]), array([92629.39]), array([23725.12713935]), array([73837.2])]
# 4
# [array([15377.05]), array([54868.41364738]), array([43465.96666667]), array([9068.1]), array([41604.81203111]), array([61657.6])]
# 3
# [array([24515.82]), array([12263.77217584]), array([165943.]), array([24362.87]), array([17729.82990774]), array([26149.2])]
# 1
# [array([299819.67]), array([218491.28214231]), array([421775.92]), array([345875.6]), array([128585.31631815]), array([247943.8])]
# 4
# [array([40261.3]), array([70797.91917786]), array([100744.83969466]), array([74901.2]), array([38779.96534443]), array([20539.9])]
# 5
# [array([329110.39]), array([265267.52274386]), array([340414.62015504]), array([312292.84]), array([307690.04193324]), array([209847.1])]
# 5
# [array([50049.23]), array([48674.52183049]), array([139100.70731707]), array([42601.67]), array([71249.94898626]), array([51079.3])]
# 3
# [array([79445.38]), array([9771.64528697]), array([93933.66666667]), array([58027.14]), array([6937.13333762]), array([89919.4])]
# 4
# [array([223356.92]), array([369597.91879458]), array([318871.55263158]), array([314553.18]), array([247779.45974476]), array([166660.6])]
# 5
# [array([6837.96]), array([4737.20366411]), array([150313.]), array([13533.26]), array([2391.80619809]), array([5949.4])]
# 4
# [array([103537.72]), array([271107.65105752]), array([79621.60273973]), array([175696.02]), array([385603.49575527]), array([237644.7])]
# 2
# [array([398767.22]), array([410029.68843546]), array([350532.03333333]), array([332948.87]), array([527903.11983084]), array([377045.4])]
# 3
# [array([364267.57]), array([231615.01546146]), array([281861.23140496]), array([397831.09]), array([252700.64852791]), array([299380.7])]
# 1
# [array([101415.24]), array([83966.72459035]), array([25605.104]), array([153854.57]), array([44811.88139319]), array([174366.])]
# 2
# [array([395753.36]), array([431207.4222896]), array([352414.98684211]), array([486576.07]), array([346434.45916719]), array([406972.2])]
# 4
# [array([47956.26]), array([56398.70544701]), array([112129.42028985]), array([9385.81]), array([90070.41353615]), array([96361.5])]
# 3
# [array([63788.81]), array([88161.38474929]), array([15799.01315789]), array([65041.75]), array([142453.86990845]), array([7270.1])]
# 5
# [array([606.39]), array([12783.6279706]), array([136000.]), array([1878.26]), array([7906.68603085]), array([4515.7])]
# 0
# [array([127607.84]), array([35957.54272698]), array([55299.76859504]), array([83680.71]), array([99400.34176675]), array([259995.6])]
# 1
# [array([207648.61]), array([177625.14770982]), array([144437.87401575]), array([197212.27]), array([263438.18616397]), array([223598.6])]
# 2
# [array([69805.53]), array([102013.10773119]), array([12312.34285714]), array([97717.57]), array([39196.62343146]), array([4403.9])]
# 5
# [array([68029.04]), array([99915.82803612]), array([73224.12598425]), array([99245.27]), array([105452.20009015]), array([47676.1])]
# 5
# [array([80972.05]), array([123746.56865203]), array([25560.83333333]), array([101878.27]), array([125147.11871548]), array([69928.2])]
# 2
# [array([9724.61]), array([19945.90328404]), array([170858.]), array([12452.58]), array([9654.68449482]), array([14497.6])]
# 4
# [array([299026.57]), array([244901.9697643]), array([312715.98366013]), array([286348.87]), array([271393.80913098]), array([342917.2])]
# 1
# [array([195745.06]), array([150110.1476653]), array([243994.34285714]), array([110605.09]), array([132942.52347369]), array([136389.4])]
# 3
# [array([29988.21]), array([18326.29053148]), array([46130.12598425]), array([21080.88]), array([53370.93458617]), array([64842.6])]
# 1
# [array([34091.83]), array([36167.37053509]), array([3774.]), array([21971.99]), array([21523.88653989]), array([31803.1])]
# 2
# [array([16032.29]), array([16430.5224223]), array([144861.]), array([10412.88]), array([10938.0645255]), array([20846.4])]
# 3
# [array([278562.38]), array([272975.37139748]), array([258827.85714286]), array([282716.58]), array([231354.23998962]), array([279732.3])]
# 4
# [array([179383.13]), array([244323.23405411]), array([338979.65217391]), array([200795.37]), array([158977.53286491]), array([206622.4])]
# 4
# [array([71378.26]), array([103691.7563868]), array([196096.69565217]), array([40699.41]), array([33522.47263279]), array([79809.3])]
# 4
# [array([46689.35]), array([95163.13741767]), array([91509.09821429]), array([19385.13]), array([39319.8127797]), array([124292.5])]
# 3
# [array([171756.61]), array([94044.50014698]), array([77568.16030534]), array([174624.85]), array([245434.94127685]), array([185069.2])]
# 2
# [array([105396.05]), array([107018.67389824]), array([162080.70731707]), array([109803.39]), array([100144.18298893]), array([110783.8])]
# 4
# [array([9000.14]), array([40890.50179701]), array([51518.33031674]), array([129514.56]), array([134094.40655647]), array([81531.8])]
# 0
# [array([10918.8]), array([12201.19247344]), array([75174.]), array([2981.09]), array([4236.20526918]), array([13723.])]
# 3
# [array([35663.42]), array([47256.19303751]), array([142488.69565217]), array([43245.76]), array([61364.61692446]), array([21580.3])]
# 5
# [array([128423.52]), array([10403.83897059]), array([119840.70731707]), array([96996.16]), array([122167.25013811]), array([117547.3])]
# 1
# [array([84746.7]), array([6877.3531631]), array([141233.50515464]), array([111084.96]), array([7724.145142]), array([61803.7])]
# 1
# [array([207975.44]), array([117839.55375399]), array([44868.47368421]), array([99421.08]), array([208573.6705821]), array([106856.8])]
# 2
# [array([218082.78]), array([320479.07038071]), array([244750.70512821]), array([296064.71]), array([218862.51438068]), array([209204.5])]
# 5
# [array([217715.38]), array([325190.61773314]), array([261100.93181818]), array([228214.09]), array([199018.45142727]), array([293246.5])]
# 4
# [array([33144.28]), array([70869.34121745]), array([14947.13861386]), array([7763.77]), array([110351.92350355]), array([105334.4])]
# 3
# [array([1640.81]), array([7702.19305101]), array([129081.]), array([6466.86]), array([4759.15745893]), array([3157.6])]
# 0
# [array([15098.88]), array([22863.66326919]), array([119717.5]), array([12271.9]), array([25779.04323815]), array([23943.])]
# 3
# [array([152699.68]), array([126327.87971254]), array([67896.16030534]), array([42904.43]), array([184090.89342228]), array([111584.1])]
# 3
# [array([40503.43]), array([59069.94233833]), array([9086.65714286]), array([78914.15]), array([138745.53325703]), array([43727.8])]
# 2
# [array([35127.07]), array([43698.17012525]), array([86160.5]), array([32805.21]), array([29436.76304477]), array([38606.5])]
# 4
# [array([197286.59]), array([102978.54014134]), array([84769.90178571]), array([177443.59]), array([232708.46513508]), array([207364.9])]
# 2
# [array([5850.92]), array([28452.42941704]), array([111010.5]), array([5733.39]), array([17764.86287245]), array([11017.9])]
# 3
# ('Best model : 2', [25, 44, 25, 38, 32, 36])
