# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
from lazypredict.Supervised import LazyRegressor

# %%
df = pd.read_csv("./data/new_kolektor_data.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             1000 non-null   int64
#  1   debtor_volume_handled  1000 non-null   float64
#  2   bill_amount_collected  1000 non-null   float64
#  3   total_actual           1000 non-null   float64
#  4   success_rate           1000 non-null   float64
#  5   avg_bill_methods       1000 non-null   int64
#  6   total_cost             1000 non-null   int64
# dtypes: float64(4), int64(3)
# memory usage: 54.8 KB

# %%
for i in df.columns:
    if df[i].dtype == "object":
        df[i] = df[i].astype("category")

df.drop(["Unnamed: 0"], axis=1, inplace=True)

# %%
df.head()
# Out:
#    debtor_volume_handled  bill_amount_collected  total_actual  success_rate  \
# 0                   7.00            14400000.00   35700000.00         40.00
# 1                  35.00            79000000.00  160500000.00         49.00
# 2                   6.00             7100000.00   26700000.00         27.00
# 3                  63.00           782000000.00 1395000000.00         56.00
# 4                  35.00           346000000.00  485500000.00         71.00
#
#    avg_bill_methods  total_cost
# 0                 0      277706
# 1                 2    22382611
# 2                 0      205389
# 3                 3   482942548
# 4                 3   151035603

# %%
df["avg_bill_methods"].value_counts()
# Out:
# avg_bill_methods
# 3    481
# 0    198
# 2    162
# 1    159
# Name: count, dtype: int64

# %%
bill_methods = {"sms or WA": 0, "surat panggilan": 1, "panggilan": 2, "datang ke tempat": 3}
columns = {"avg_bill_methods": bill_methods}
for i in df.columns:
    if df[i].dtype == "category" or df[i].dtype == "object":
        df[i] = [columns[i][j] for j in df[i]]

y = df["total_cost"]
df.drop("total_cost", axis=1, inplace=True)             
scaler = RobustScaler().fit(df[[i for i in df.columns if i not in columns]])
df2 = pd.DataFrame(scaler.transform(df[[i for i in df.columns if i not in columns]]), columns=df[[i for i in df.columns if i not in columns]].columns)
for i in columns:
    df2[i] = df[i]
df2.head(5)
# Out:
#    debtor_volume_handled  bill_amount_collected  total_actual  success_rate  \
# 0                  -1.35                  -0.46         -0.52         -0.36
# 1                  -0.13                  -0.28         -0.34         -0.16
# 2                  -1.39                  -0.48         -0.53         -0.66
# 3                   1.09                   1.64          1.39          0.00
# 4                  -0.13                   0.45          0.11          0.34
#
#    avg_bill_methods
# 0                 0
# 1                 2
# 2                 0
# 3                 3
# 4                 3

# %%
X = df2

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42)
reg = LazyRegressor(verbose=0, ignore_warnings=True)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)
models
# Out:
#   5%|▍         | 2/42 [00:00<00:06,  6.43it/s]
# 100%|██████████| 42/42 [00:07<00:00,  5.48it/s]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001098 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 679
# [LightGBM] [Info] Number of data points in the train set: 800, number of used features: 5
# [LightGBM] [Info] Start training from score 134930141.780000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#                                Adjusted R-Squared  R-Squared          RMSE  \
# Model
# AdaBoostRegressor                            0.68       0.69   97184954.07
# PoissonRegressor                             0.67       0.68   98871786.47
# GradientBoostingRegressor                    0.60       0.61  108825481.03
# RandomForestRegressor                        0.60       0.61  108917299.33
# KNeighborsRegressor                          0.59       0.60  110029705.51
# BaggingRegressor                             0.59       0.60  110093564.67
# LGBMRegressor                                0.58       0.59  112149286.42
# HistGradientBoostingRegressor                0.56       0.58  113710946.80
# SGDRegressor                                 0.56       0.57  114855902.57
# LinearRegression                             0.56       0.57  114921995.36
# TransformedTargetRegressor                   0.56       0.57  114921995.36
# Lars                                         0.56       0.57  114921995.36
# LassoLars                                    0.56       0.57  114921995.48
# Lasso                                        0.56       0.57  114921995.48
# Ridge                                        0.56       0.57  114926530.24
# RidgeCV                                      0.55       0.57  114973772.29
# OrthogonalMatchingPursuitCV                  0.55       0.57  114982367.89
# LassoLarsIC                                  0.55       0.57  115019739.14
# LarsCV                                       0.55       0.57  115060988.18
# LassoLarsCV                                  0.55       0.57  115103076.64
# LassoCV                                      0.55       0.57  115104520.33
# ExtraTreesRegressor                          0.55       0.56  115131087.38
# ElasticNet                                   0.53       0.54  118543400.69
# TweedieRegressor                             0.50       0.51  122430969.10
# XGBRegressor                                 0.48       0.50  123727024.15
# OrthogonalMatchingPursuit                    0.48       0.50  123937585.14
# GammaRegressor                               0.38       0.40  135665557.59
# DecisionTreeRegressor                        0.30       0.32  144103183.00
# ExtraTreeRegressor                           0.22       0.24  152411595.66
# HuberRegressor                              -0.00       0.02  172592480.99
# ElasticNetCV                                -0.04      -0.02  176107841.93
# BayesianRidge                               -0.04      -0.02  176110331.07
# DummyRegressor                              -0.04      -0.02  176110331.07
# NuSVR                                       -0.09      -0.06  179939573.92
# RANSACRegressor                             -0.13      -0.10  182846399.88
# KernelRidge                                 -0.15      -0.12  184540875.98
# SVR                                         -0.36      -0.32  200873517.45
# PassiveAggressiveRegressor                  -0.86      -0.81  235004357.53
# LinearSVR                                   -0.87      -0.82  235725377.09
# MLPRegressor                                -0.87      -0.82  235725607.26
# GaussianProcessRegressor                  -495.86    -483.38 3841223952.49
#
#                                Time Taken
# Model
# AdaBoostRegressor                    0.12
# PoissonRegressor                     0.02
# GradientBoostingRegressor            0.52
# RandomForestRegressor                1.29
# KNeighborsRegressor                  0.04
# BaggingRegressor                     0.18
# LGBMRegressor                        0.17
# HistGradientBoostingRegressor        1.17
# SGDRegressor                         0.01
# LinearRegression                     0.02
# TransformedTargetRegressor           0.01
# Lars                                 0.04
# LassoLars                            0.02
# Lasso                                0.02
# Ridge                                0.02
# RidgeCV                              0.01
# OrthogonalMatchingPursuitCV          0.03
# LassoLarsIC                          0.02
# LarsCV                               0.05
# LassoLarsCV                          0.03
# LassoCV                              0.18
# ExtraTreesRegressor                  0.93
# ElasticNet                           0.03
# TweedieRegressor                     0.03
# XGBRegressor                         0.24
# OrthogonalMatchingPursuit            0.02
# GammaRegressor                       0.28
# DecisionTreeRegressor                0.03
# ExtraTreeRegressor                   0.03
# HuberRegressor                       0.05
# ElasticNetCV                         0.18
# BayesianRidge                        0.02
# DummyRegressor                       0.02
# NuSVR                                0.13
# RANSACRegressor                      0.16
# KernelRidge                          0.08
# SVR                                  0.07
# PassiveAggressiveRegressor           0.08
# LinearSVR                            0.03
# MLPRegressor                         1.09
# GaussianProcessRegressor             0.17

# %%
y.describe()
# Out:
# count        1000.00
# mean    139633105.12
# std     166600490.67
# min         25263.00
# 25%       1928856.50
# 50%      62215627.00
# 75%     247064723.00
# max     678041154.00
# Name: total_cost, dtype: float64

# %%
X = df2.drop("success_rate", axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42)
reg = LazyRegressor(verbose=0, ignore_warnings=True)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)
models
# Out:
#   2%|▏         | 1/42 [00:00<00:04,  9.66it/s]
# 100%|██████████| 42/42 [00:06<00:00,  6.40it/s]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000125 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 800, number of used features: 4
# [LightGBM] [Info] Start training from score 134930141.780000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#                                Adjusted R-Squared  R-Squared           RMSE  \
# Model
# PoissonRegressor                             0.67       0.68    98985045.33
# AdaBoostRegressor                            0.67       0.67    99715067.53
# GradientBoostingRegressor                    0.62       0.63   106519238.09
# RandomForestRegressor                        0.61       0.62   108135738.42
# HistGradientBoostingRegressor                0.60       0.61   108703283.03
# BaggingRegressor                             0.60       0.60   109778120.47
# LGBMRegressor                                0.59       0.60   110270695.87
# KNeighborsRegressor                          0.58       0.59   111747372.72
# SGDRegressor                                 0.55       0.56   115339482.09
# OrthogonalMatchingPursuitCV                  0.55       0.56   115368966.15
# LinearRegression                             0.55       0.56   115368966.15
# LassoLarsIC                                  0.55       0.56   115368966.15
# Lars                                         0.55       0.56   115368966.15
# TransformedTargetRegressor                   0.55       0.56   115368966.15
# LassoLars                                    0.55       0.56   115368966.18
# Lasso                                        0.55       0.56   115368966.19
# Ridge                                        0.55       0.56   115373148.81
# LassoLarsCV                                  0.55       0.56   115385449.04
# LarsCV                                       0.55       0.56   115385449.04
# RidgeCV                                      0.55       0.56   115413746.67
# LassoCV                                      0.55       0.56   115414355.94
# ElasticNet                                   0.53       0.54   118716411.77
# ExtraTreesRegressor                          0.51       0.52   120714985.77
# TweedieRegressor                             0.50       0.51   122556609.68
# OrthogonalMatchingPursuit                    0.49       0.50   123937585.14
# XGBRegressor                                 0.45       0.46   128490807.61
# GammaRegressor                               0.39       0.40   135111648.04
# ExtraTreeRegressor                           0.29       0.31   145320543.71
# DecisionTreeRegressor                        0.25       0.27   149474633.48
# RANSACRegressor                              0.12       0.14   161984757.19
# HuberRegressor                               0.00       0.02   172621407.49
# ElasticNetCV                                -0.04      -0.02   176107851.26
# BayesianRidge                               -0.04      -0.02   176110331.07
# DummyRegressor                              -0.04      -0.02   176110331.07
# NuSVR                                       -0.08      -0.06   179939558.32
# KernelRidge                                 -0.14      -0.12   184703644.83
# SVR                                         -0.35      -0.32   200873509.10
# PassiveAggressiveRegressor                  -0.85      -0.81   235003709.61
# LinearSVR                                   -0.86      -0.82   235725377.09
# MLPRegressor                                -0.86      -0.82   235725552.68
# GaussianProcessRegressor                -24231.11  -23744.03 26894588983.29
#
#                                Time Taken
# Model
# PoissonRegressor                     0.02
# AdaBoostRegressor                    0.10
# GradientBoostingRegressor            0.41
# RandomForestRegressor                1.19
# HistGradientBoostingRegressor        0.79
# BaggingRegressor                     0.14
# LGBMRegressor                        0.14
# KNeighborsRegressor                  0.03
# SGDRegressor                         0.12
# OrthogonalMatchingPursuitCV          0.03
# LinearRegression                     0.02
# LassoLarsIC                          0.02
# Lars                                 0.03
# TransformedTargetRegressor           0.03
# LassoLars                            0.03
# Lasso                                0.02
# Ridge                                0.03
# LassoLarsCV                          0.04
# LarsCV                               0.04
# RidgeCV                              0.05
# LassoCV                              0.18
# ElasticNet                           0.03
# ExtraTreesRegressor                  0.82
# TweedieRegressor                     0.03
# OrthogonalMatchingPursuit            0.02
# XGBRegressor                         0.17
# GammaRegressor                       0.02
# ExtraTreeRegressor                   0.02
# DecisionTreeRegressor                0.03
# RANSACRegressor                      0.11
# HuberRegressor                       0.05
# ElasticNetCV                         0.16
# BayesianRidge                        0.02
# DummyRegressor                       0.02
# NuSVR                                0.11
# KernelRidge                          0.07
# SVR                                  0.20
# PassiveAggressiveRegressor           0.09
# LinearSVR                            0.02
# MLPRegressor                         0.92
# GaussianProcessRegressor             0.17
